# %% [markdown]
# # WeatherAPI (Weather)
#
# Answer the following questions using [WeatherAPI](http://www.weatherapi.com/). I've added three cells for most questions but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# Be sure to take advantage of both the documentation and the API Explorer!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*
# - *Tip: Remember you only need to import requests once!*

# %%
import requests

# %% [markdown]
# ## 1) Make a request to the Weather API for where you were born (or lived, or want to visit!).
#
# - *Tip: This sure seems familiar.*

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key_weather}&q=Cordoba&aqi=no")

# %%
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'Cordoba',
#   'region': 'Cordoba',
#   'country': 'Argentina',
#   'lat': -31.4,
#   'lon': -64.18,
#   'tz_id': 'America/Argentina/Cordoba',
#   'localtime_epoch': 1624215872,
#   'localtime': '2021-06-20 16:04'},
#  'current': {'last_updated_epoch': 1624212000,
#   'last_updated': '2021-06-20 15:00',
#   'temp_c': 12.0,
#   'temp_f': 53.6,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 15.0,
#   'wind_kph': 24.1,
#   'wind_degree': 40,
#   'wind_dir': 'NE',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.5,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 58,
#   'cloud': 50,
#   'feelslike_c': 9.8,
#   'feelslike_f': 49.6,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 4.0,
#   'gust_mph': 15.2,
#   'gust_kph': 24.5}}

# %% [markdown]
# ## 2) What's the current wind speed, and how much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference. Same as we did last time!*

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
f"The wind speed is {data['current']['wind_mph']} mph"
# Out:
# 'The wind speed is 9.4 mph'

# %%
f"The temperature is {round(data['current']['temp_f'] - data['current']['feelslike_f'], 2)} degrees warmer"
# Out:
# 'The temperature is 2.2 degrees warmer'

# %% [markdown]
# ## 3) What is the API endpoint for moon-related information? For the place you decided on above, how much of the moon will be visible on next Thursday?
#
# - *Tip: Check the documentation!*
# - *Tip: If you aren't sure what something means, ask in Slack*

# %%
response = requests.get(f"http://api.weatherapi.com/v1/astronomy.json?key={api_key_weather}&q=Cordoba&dt=2021-06-24")

# %%
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'Cordoba',
#   'region': 'Cordoba',
#   'country': 'Argentina',
#   'lat': -31.4,
#   'lon': -64.18,
#   'tz_id': 'America/Argentina/Cordoba',
#   'localtime_epoch': 1624215900,
#   'localtime': '2021-06-20 16:05'},
#  'astronomy': {'astro': {'sunrise': '08:16 AM',
#    'sunset': '06:22 PM',
#    'moonrise': '06:19 PM',
#    'moonset': '08:06 AM',
#    'moon_phase': 'Full Moon',
#    'moon_illumination': '100'}}}

# %%
data.keys()
# Out:
# dict_keys(['location', 'astronomy'])

# %%
data['astronomy'].keys()
# Out:
# dict_keys(['astro'])

# %%
f"The moon will be {data['astronomy']['astro']['moon_illumination']}% visible next Thursday"
# Out:
# 'The moon will be 100% visible next Thursday'

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?
#
# - *Tip: When you requested moon data, you probably overwrote your variables! If so, you'll need to make a new request.*

# %%
response = requests.get(f"http://api.weatherapi.com/v1/forecast.json?key={api_key_weather}&q=Cordoba&days=1&aqi=no&alerts=no")

# %%
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'Cordoba',
#   'region': 'Cordoba',
#   'country': 'Argentina',
#   'lat': -31.4,
#   'lon': -64.18,
#   'tz_id': 'America/Argentina/Cordoba',
#   'localtime_epoch': 1624215915,
#   'localtime': '2021-06-20 16:05'},
#  'current': {'last_updated_epoch': 1624212000,
#   'last_updated': '2021-06-20 15:00',
#   'temp_c': 12.0,
#   'temp_f': 53.6,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 15.0,
#   'wind_kph': 24.1,
#   'wind_degree': 40,
#   'wind_dir': 'NE',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.5,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 58,
#   'cloud': 50,
#   'feelslike_c': 9.8,
#   'feelslike_f': 49.6,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 4.0,
#   'gust_mph': 15.2,
#   'gust_kph': 24.5},
#  'forecast': {'forecastday': [{'date': '2021-06-20',
#     'date_epoch': 1624147200,
#     'day': {'maxtemp_c': 14.4,
#      'maxtemp_f': 57.9,
#      'mintemp_c': 4.3,
#      'mintemp_f': 39.7,
#      'avgtemp_c': 8.0,
#      'avgtemp_f': 46.4,
#      'maxwind_mph': 15.2,
#      'maxwind_kph': 24.5,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 70.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': '0',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 3.0},
#     'astro': {'sunrise': '08:15 AM',
#      'sunset': '06:22 PM',
#      'moonrise': '03:07 PM',
#      'moonset': '03:23 AM',
#      'moon_phase': 'Full Moon',
#      'moon_illumination': '76'},
#     'hour': [{'time_epoch': 1624158000,
#       'time': '2021-06-20 00:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 9,
#       'wind_dir': 'N',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 0,
#       'feelslike_c': 2.9,
#       'feelslike_f': 37.2,
#       'windchill_c': 2.9,
#       'windchill_f': 37.2,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.9,
#       'dewpoint_f': 35.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.2,
#       'uv': 1.0},
#      {'time_epoch': 1624161600,
#       'time': '2021-06-20 01:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 7,
#       'wind_dir': 'N',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 0,
#       'feelslike_c': 3.0,
#       'feelslike_f': 37.4,
#       'windchill_c': 3.0,
#       'windchill_f': 37.4,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.9,
#       'dewpoint_f': 35.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.4,
#       'uv': 1.0},
#      {'time_epoch': 1624165200,
#       'time': '2021-06-20 02:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 0,
#       'feelslike_c': 3.1,
#       'feelslike_f': 37.6,
#       'windchill_c': 3.1,
#       'windchill_f': 37.6,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.8,
#       'dewpoint_f': 35.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 1.0},
#      {'time_epoch': 1624168800,
#       'time': '2021-06-20 03:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 3,
#       'wind_dir': 'N',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 0,
#       'feelslike_c': 3.2,
#       'feelslike_f': 37.8,
#       'windchill_c': 3.2,
#       'windchill_f': 37.8,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.8,
#       'dewpoint_f': 35.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 1.0},
#      {'time_epoch': 1624172400,
#       'time': '2021-06-20 04:00',
#       'temp_c': 5.0,
#       'temp_f': 41.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 0,
#       'feelslike_c': 2.9,
#       'feelslike_f': 37.2,
#       'windchill_c': 2.9,
#       'windchill_f': 37.2,
#       'heatindex_c': 5.0,
#       'heatindex_f': 41.0,
#       'dewpoint_c': 1.7,
#       'dewpoint_f': 35.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 1.0},
#      {'time_epoch': 1624176000,
#       'time': '2021-06-20 05:00',
#       'temp_c': 4.6,
#       'temp_f': 40.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 0,
#       'feelslike_c': 2.6,
#       'feelslike_f': 36.7,
#       'windchill_c': 2.6,
#       'windchill_f': 36.7,
#       'heatindex_c': 4.6,
#       'heatindex_f': 40.3,
#       'dewpoint_c': 1.7,
#       'dewpoint_f': 35.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 1.0},
#      {'time_epoch': 1624179600,
#       'time': '2021-06-20 06:00',
#       'temp_c': 4.3,
#       'temp_f': 39.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 10,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 0,
#       'feelslike_c': 2.3,
#       'feelslike_f': 36.1,
#       'windchill_c': 2.3,
#       'windchill_f': 36.1,
#       'heatindex_c': 4.3,
#       'heatindex_f': 39.7,
#       'dewpoint_c': 1.6,
#       'dewpoint_f': 34.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 1.0},
#      {'time_epoch': 1624183200,
#       'time': '2021-06-20 07:00',
#       'temp_c': 4.5,
#       'temp_f': 40.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 0,
#       'feelslike_c': 2.5,
#       'feelslike_f': 36.5,
#       'windchill_c': 2.5,
#       'windchill_f': 36.5,
#       'heatindex_c': 4.5,
#       'heatindex_f': 40.1,
#       'dewpoint_c': 1.6,
#       'dewpoint_f': 34.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0},
#      {'time_epoch': 1624186800,
#       'time': '2021-06-20 08:00',
#       'temp_c': 4.6,
#       'temp_f': 40.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 0,
#       'feelslike_c': 2.7,
#       'feelslike_f': 36.9,
#       'windchill_c': 2.7,
#       'windchill_f': 36.9,
#       'heatindex_c': 4.6,
#       'heatindex_f': 40.3,
#       'dewpoint_c': 1.5,
#       'dewpoint_f': 34.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.2,
#       'gust_kph': 14.8,
#       'uv': 1.0},
#      {'time_epoch': 1624190400,
#       'time': '2021-06-20 09:00',
#       'temp_c': 4.8,
#       'temp_f': 40.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 2,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 0,
#       'feelslike_c': 2.9,
#       'feelslike_f': 37.2,
#       'windchill_c': 2.9,
#       'windchill_f': 37.2,
#       'heatindex_c': 4.8,
#       'heatindex_f': 40.6,
#       'dewpoint_c': 1.5,
#       'dewpoint_f': 34.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 2.0},
#      {'time_epoch': 1624194000,
#       'time': '2021-06-20 10:00',
#       'temp_c': 7.1,
#       'temp_f': 44.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 11,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 8,
#       'feelslike_c': 5.1,
#       'feelslike_f': 41.2,
#       'windchill_c': 5.1,
#       'windchill_f': 41.2,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.8,
#       'dewpoint_c': 2.1,
#       'dewpoint_f': 35.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 3.0},
#      {'time_epoch': 1624197600,
#       'time': '2021-06-20 11:00',
#       'temp_c': 9.3,
#       'temp_f': 48.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 20,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 16,
#       'feelslike_c': 7.2,
#       'feelslike_f': 45.0,
#       'windchill_c': 7.2,
#       'windchill_f': 45.0,
#       'heatindex_c': 9.3,
#       'heatindex_f': 48.7,
#       'dewpoint_c': 2.7,
#       'dewpoint_f': 36.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 3.0},
#      {'time_epoch': 1624201200,
#       'time': '2021-06-20 12:00',
#       'temp_c': 11.6,
#       'temp_f': 52.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 29,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 25,
#       'feelslike_c': 9.4,
#       'feelslike_f': 48.9,
#       'windchill_c': 9.4,
#       'windchill_f': 48.9,
#       'heatindex_c': 11.6,
#       'heatindex_f': 52.9,
#       'dewpoint_c': 3.3,
#       'dewpoint_f': 37.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 4.0},
#      {'time_epoch': 1624204800,
#       'time': '2021-06-20 13:00',
#       'temp_c': 12.5,
#       'temp_f': 54.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.2,
#       'wind_kph': 21.2,
#       'wind_degree': 32,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 54,
#       'cloud': 22,
#       'feelslike_c': 10.5,
#       'feelslike_f': 50.9,
#       'windchill_c': 10.5,
#       'windchill_f': 50.9,
#       'heatindex_c': 12.5,
#       'heatindex_f': 54.5,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 4.0},
#      {'time_epoch': 1624208400,
#       'time': '2021-06-20 14:00',
#       'temp_c': 13.5,
#       'temp_f': 56.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 14.3,
#       'wind_kph': 23.0,
#       'wind_degree': 35,
#       'wind_dir': 'NE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 20,
#       'feelslike_c': 11.5,
#       'feelslike_f': 52.7,
#       'windchill_c': 11.5,
#       'windchill_f': 52.7,
#       'heatindex_c': 13.5,
#       'heatindex_f': 56.3,
#       'dewpoint_c': 3.5,
#       'dewpoint_f': 38.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.3,
#       'gust_kph': 26.3,
#       'uv': 4.0},
#      {'time_epoch': 1624212000,
#       'time': '2021-06-20 15:00',
#       'temp_c': 14.4,
#       'temp_f': 57.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.2,
#       'wind_kph': 24.5,
#       'wind_degree': 39,
#       'wind_dir': 'NE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 18,
#       'feelslike_c': 12.6,
#       'feelslike_f': 54.7,
#       'windchill_c': 12.6,
#       'windchill_f': 54.7,
#       'heatindex_c': 14.4,
#       'heatindex_f': 57.9,
#       'dewpoint_c': 3.6,
#       'dewpoint_f': 38.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 28.1,
#       'uv': 4.0},
#      {'time_epoch': 1624215600,
#       'time': '2021-06-20 16:00',
#       'temp_c': 13.2,
#       'temp_f': 55.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 14.1,
#       'wind_kph': 22.7,
#       'wind_degree': 41,
#       'wind_dir': 'NE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 19,
#       'feelslike_c': 11.3,
#       'feelslike_f': 52.3,
#       'windchill_c': 11.3,
#       'windchill_f': 52.3,
#       'heatindex_c': 13.2,
#       'heatindex_f': 55.8,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.9,
#       'gust_kph': 28.8,
#       'uv': 4.0},
#      {'time_epoch': 1624219200,
#       'time': '2021-06-20 17:00',
#       'temp_c': 12.1,
#       'temp_f': 53.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 43,
#       'wind_dir': 'NE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 55,
#       'cloud': 20,
#       'feelslike_c': 9.9,
#       'feelslike_f': 49.8,
#       'windchill_c': 9.9,
#       'windchill_f': 49.8,
#       'heatindex_c': 12.1,
#       'heatindex_f': 53.8,
#       'dewpoint_c': 3.3,
#       'dewpoint_f': 37.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.6,
#       'gust_kph': 29.9,
#       'uv': 4.0},
#      {'time_epoch': 1624222800,
#       'time': '2021-06-20 18:00',
#       'temp_c': 10.9,
#       'temp_f': 51.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 46,
#       'wind_dir': 'NE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 21,
#       'feelslike_c': 8.6,
#       'feelslike_f': 47.5,
#       'windchill_c': 8.6,
#       'windchill_f': 47.5,
#       'heatindex_c': 10.9,
#       'heatindex_f': 51.6,
#       'dewpoint_c': 3.1,
#       'dewpoint_f': 37.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.0,
#       'gust_kph': 30.6,
#       'uv': 4.0},
#      {'time_epoch': 1624226400,
#       'time': '2021-06-20 19:00',
#       'temp_c': 9.8,
#       'temp_f': 49.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 149,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 33,
#       'feelslike_c': 7.6,
#       'feelslike_f': 45.7,
#       'windchill_c': 7.6,
#       'windchill_f': 45.7,
#       'heatindex_c': 9.8,
#       'heatindex_f': 49.6,
#       'dewpoint_c': 3.2,
#       'dewpoint_f': 37.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 28.1,
#       'uv': 1.0},
#      {'time_epoch': 1624230000,
#       'time': '2021-06-20 20:00',
#       'temp_c': 8.7,
#       'temp_f': 47.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 252,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 44,
#       'feelslike_c': 6.5,
#       'feelslike_f': 43.7,
#       'windchill_c': 6.5,
#       'windchill_f': 43.7,
#       'heatindex_c': 8.7,
#       'heatindex_f': 47.7,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.1,
#       'gust_kph': 25.9,
#       'uv': 1.0},
#      {'time_epoch': 1624233600,
#       'time': '2021-06-20 21:00',
#       'temp_c': 7.6,
#       'temp_f': 45.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 356,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 56,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 7.6,
#       'heatindex_f': 45.7,
#       'dewpoint_c': 3.5,
#       'dewpoint_f': 38.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.4,
#       'uv': 1.0},
#      {'time_epoch': 1624237200,
#       'time': '2021-06-20 22:00',
#       'temp_c': 7.5,
#       'temp_f': 45.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 45,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 7.5,
#       'heatindex_f': 45.5,
#       'dewpoint_c': 3.6,
#       'dewpoint_f': 38.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.9,
#       'gust_kph': 22.3,
#       'uv': 1.0},
#      {'time_epoch': 1624240800,
#       'time': '2021-06-20 23:00',
#       'temp_c': 7.3,
#       'temp_f': 45.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 33,
#       'feelslike_c': 5.4,
#       'feelslike_f': 41.7,
#       'windchill_c': 5.4,
#       'windchill_f': 41.7,
#       'heatindex_c': 7.3,
#       'heatindex_f': 45.1,
#       'dewpoint_c': 3.7,
#       'dewpoint_f': 38.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 20.9,
#       'uv': 1.0}]}]}}

# %%
data['forecast']['forecastday']
# Out:
# [{'date': '2021-06-19',
#   'date_epoch': 1624060800,
#   'day': {'maxtemp_c': 10.7,
#    'maxtemp_f': 51.3,
#    'mintemp_c': 3.9,
#    'mintemp_f': 39.0,
#    'avgtemp_c': 6.7,
#    'avgtemp_f': 44.0,
#    'maxwind_mph': 8.9,
#    'maxwind_kph': 14.4,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 74.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'uv': 3.0},
#   'astro': {'sunrise': '08:15 AM',
#    'sunset': '06:21 PM',
#    'moonrise': '02:32 PM',
#    'moonset': '02:17 AM',
#    'moon_phase': 'Waxing Gibbous',
#    'moon_illumination': '69'},
#   'hour': [{'time_epoch': 1624071600,
#     'time': '2021-06-19 00:00',
#     'temp_c': 5.7,
#     'temp_f': 42.3,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 10,
#     'wind_dir': 'N',
#     'pressure_mb': 1028.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 100,
#     'feelslike_c': 4.4,
#     'feelslike_f': 39.9,
#     'windchill_c': 4.4,
#     'windchill_f': 39.9,
#     'heatindex_c': 5.7,
#     'heatindex_f': 42.3,
#     'dewpoint_c': 1.6,
#     'dewpoint_f': 34.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.3,
#     'gust_kph': 10.1,
#     'uv': 1.0},
#    {'time_epoch': 1624075200,
#     'time': '2021-06-19 01:00',
#     'temp_c': 5.6,
#     'temp_f': 42.1,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 12,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 93,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.7,
#     'windchill_c': 4.3,
#     'windchill_f': 39.7,
#     'heatindex_c': 5.6,
#     'heatindex_f': 42.1,
#     'dewpoint_c': 1.6,
#     'dewpoint_f': 34.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 1.0},
#    {'time_epoch': 1624078800,
#     'time': '2021-06-19 02:00',
#     'temp_c': 5.6,
#     'temp_f': 42.1,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 13,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 86,
#     'feelslike_c': 4.1,
#     'feelslike_f': 39.4,
#     'windchill_c': 4.1,
#     'windchill_f': 39.4,
#     'heatindex_c': 5.6,
#     'heatindex_f': 42.1,
#     'dewpoint_c': 1.5,
#     'dewpoint_f': 34.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 1.0},
#    {'time_epoch': 1624082400,
#     'time': '2021-06-19 03:00',
#     'temp_c': 5.5,
#     'temp_f': 41.9,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 15,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 80,
#     'feelslike_c': 4.0,
#     'feelslike_f': 39.2,
#     'windchill_c': 4.0,
#     'windchill_f': 39.2,
#     'heatindex_c': 5.5,
#     'heatindex_f': 41.9,
#     'dewpoint_c': 1.5,
#     'dewpoint_f': 34.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624086000,
#     'time': '2021-06-19 04:00',
#     'temp_c': 5.0,
#     'temp_f': 41.0,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 17,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 84,
#     'feelslike_c': 3.5,
#     'feelslike_f': 38.3,
#     'windchill_c': 3.5,
#     'windchill_f': 38.3,
#     'heatindex_c': 5.0,
#     'heatindex_f': 41.0,
#     'dewpoint_c': 1.7,
#     'dewpoint_f': 35.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624089600,
#     'time': '2021-06-19 05:00',
#     'temp_c': 4.4,
#     'temp_f': 39.9,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 18,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 83,
#     'cloud': 89,
#     'feelslike_c': 2.9,
#     'feelslike_f': 37.2,
#     'windchill_c': 2.9,
#     'windchill_f': 37.2,
#     'heatindex_c': 4.4,
#     'heatindex_f': 39.9,
#     'dewpoint_c': 1.8,
#     'dewpoint_f': 35.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624093200,
#     'time': '2021-06-19 06:00',
#     'temp_c': 3.9,
#     'temp_f': 39.0,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 20,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 93,
#     'feelslike_c': 2.4,
#     'feelslike_f': 36.3,
#     'windchill_c': 2.4,
#     'windchill_f': 36.3,
#     'heatindex_c': 3.9,
#     'heatindex_f': 39.0,
#     'dewpoint_c': 2.0,
#     'dewpoint_f': 35.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624096800,
#     'time': '2021-06-19 07:00',
#     'temp_c': 4.4,
#     'temp_f': 39.9,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 22,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 86,
#     'feelslike_c': 3.0,
#     'feelslike_f': 37.4,
#     'windchill_c': 3.0,
#     'windchill_f': 37.4,
#     'heatindex_c': 4.4,
#     'heatindex_f': 39.9,
#     'dewpoint_c': 2.1,
#     'dewpoint_f': 35.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.0,
#     'gust_kph': 9.7,
#     'uv': 1.0},
#    {'time_epoch': 1624100400,
#     'time': '2021-06-19 08:00',
#     'temp_c': 4.8,
#     'temp_f': 40.6,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 24,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 83,
#     'cloud': 80,
#     'feelslike_c': 3.7,
#     'feelslike_f': 38.7,
#     'windchill_c': 3.7,
#     'windchill_f': 38.7,
#     'heatindex_c': 4.8,
#     'heatindex_f': 40.6,
#     'dewpoint_c': 2.1,
#     'dewpoint_f': 35.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.6,
#     'gust_kph': 9.0,
#     'uv': 1.0},
#    {'time_epoch': 1624104000,
#     'time': '2021-06-19 09:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 26,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1028.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 73,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.7,
#     'windchill_c': 4.3,
#     'windchill_f': 39.7,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.2,
#     'dewpoint_f': 36.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.9,
#     'gust_kph': 7.9,
#     'uv': 2.0},
#    {'time_epoch': 1624107600,
#     'time': '2021-06-19 10:00',
#     'temp_c': 6.4,
#     'temp_f': 43.5,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 30,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 62,
#     'feelslike_c': 5.1,
#     'feelslike_f': 41.2,
#     'windchill_c': 5.1,
#     'windchill_f': 41.2,
#     'heatindex_c': 6.4,
#     'heatindex_f': 43.5,
#     'dewpoint_c': 2.5,
#     'dewpoint_f': 36.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.8,
#     'gust_kph': 9.4,
#     'uv': 3.0},
#    {'time_epoch': 1624111200,
#     'time': '2021-06-19 11:00',
#     'temp_c': 7.4,
#     'temp_f': 45.3,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 35,
#     'wind_dir': 'NE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 51,
#     'feelslike_c': 6.0,
#     'feelslike_f': 42.8,
#     'windchill_c': 6.0,
#     'windchill_f': 42.8,
#     'heatindex_c': 7.4,
#     'heatindex_f': 45.3,
#     'dewpoint_c': 2.8,
#     'dewpoint_f': 37.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 2.0},
#    {'time_epoch': 1624114800,
#     'time': '2021-06-19 12:00',
#     'temp_c': 8.5,
#     'temp_f': 47.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 39,
#     'wind_dir': 'NE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 69,
#     'cloud': 39,
#     'feelslike_c': 6.8,
#     'feelslike_f': 44.2,
#     'windchill_c': 6.8,
#     'windchill_f': 44.2,
#     'heatindex_c': 8.5,
#     'heatindex_f': 47.3,
#     'dewpoint_c': 3.1,
#     'dewpoint_f': 37.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 3.0},
#    {'time_epoch': 1624118400,
#     'time': '2021-06-19 13:00',
#     'temp_c': 9.2,
#     'temp_f': 48.6,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 7.4,
#     'wind_kph': 11.9,
#     'wind_degree': 42,
#     'wind_dir': 'NE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 65,
#     'cloud': 45,
#     'feelslike_c': 7.5,
#     'feelslike_f': 45.5,
#     'windchill_c': 7.5,
#     'windchill_f': 45.5,
#     'heatindex_c': 9.2,
#     'heatindex_f': 48.6,
#     'dewpoint_c': 2.9,
#     'dewpoint_f': 37.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.3,
#     'gust_kph': 13.3,
#     'uv': 3.0},
#    {'time_epoch': 1624122000,
#     'time': '2021-06-19 14:00',
#     'temp_c': 10.0,
#     'temp_f': 50.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.1,
#     'wind_kph': 13.0,
#     'wind_degree': 46,
#     'wind_dir': 'NE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 61,
#     'cloud': 50,
#     'feelslike_c': 8.1,
#     'feelslike_f': 46.6,
#     'windchill_c': 8.1,
#     'windchill_f': 46.6,
#     'heatindex_c': 10.0,
#     'heatindex_f': 50.0,
#     'dewpoint_c': 2.7,
#     'dewpoint_f': 36.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 4.0},
#    {'time_epoch': 1624125600,
#     'time': '2021-06-19 15:00',
#     'temp_c': 10.7,
#     'temp_f': 51.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.9,
#     'wind_kph': 14.4,
#     'wind_degree': 49,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 57,
#     'cloud': 56,
#     'feelslike_c': 8.8,
#     'feelslike_f': 47.8,
#     'windchill_c': 8.8,
#     'windchill_f': 47.8,
#     'heatindex_c': 10.7,
#     'heatindex_f': 51.3,
#     'dewpoint_c': 2.5,
#     'dewpoint_f': 36.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.3,
#     'gust_kph': 16.6,
#     'uv': 4.0},
#    {'time_epoch': 1624129200,
#     'time': '2021-06-19 16:00',
#     'temp_c': 9.9,
#     'temp_f': 49.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.7,
#     'wind_kph': 14.0,
#     'wind_degree': 50,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 60,
#     'cloud': 52,
#     'feelslike_c': 7.9,
#     'feelslike_f': 46.2,
#     'windchill_c': 7.9,
#     'windchill_f': 46.2,
#     'heatindex_c': 9.9,
#     'heatindex_f': 49.8,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.0,
#     'gust_kph': 17.6,
#     'uv': 3.0},
#    {'time_epoch': 1624132800,
#     'time': '2021-06-19 17:00',
#     'temp_c': 9.1,
#     'temp_f': 48.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.3,
#     'wind_kph': 13.3,
#     'wind_degree': 51,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 63,
#     'cloud': 47,
#     'feelslike_c': 7.0,
#     'feelslike_f': 44.6,
#     'windchill_c': 7.0,
#     'windchill_f': 44.6,
#     'heatindex_c': 9.1,
#     'heatindex_f': 48.4,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 3.0},
#    {'time_epoch': 1624136400,
#     'time': '2021-06-19 18:00',
#     'temp_c': 8.3,
#     'temp_f': 46.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.1,
#     'wind_kph': 13.0,
#     'wind_degree': 51,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 66,
#     'cloud': 43,
#     'feelslike_c': 6.1,
#     'feelslike_f': 43.0,
#     'windchill_c': 6.1,
#     'windchill_f': 43.0,
#     'heatindex_c': 8.3,
#     'heatindex_f': 46.9,
#     'dewpoint_c': 2.3,
#     'dewpoint_f': 36.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 3.0},
#    {'time_epoch': 1624140000,
#     'time': '2021-06-19 19:00',
#     'temp_c': 7.3,
#     'temp_f': 45.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.6,
#     'wind_kph': 12.2,
#     'wind_degree': 39,
#     'wind_dir': 'NE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 71,
#     'cloud': 30,
#     'feelslike_c': 5.1,
#     'feelslike_f': 41.2,
#     'windchill_c': 5.1,
#     'windchill_f': 41.2,
#     'heatindex_c': 7.3,
#     'heatindex_f': 45.1,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0},
#    {'time_epoch': 1624143600,
#     'time': '2021-06-19 20:00',
#     'temp_c': 6.4,
#     'temp_f': 43.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 27,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 16,
#     'feelslike_c': 4.0,
#     'feelslike_f': 39.2,
#     'windchill_c': 4.0,
#     'windchill_f': 39.2,
#     'heatindex_c': 6.4,
#     'heatindex_f': 43.5,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 1.0},
#    {'time_epoch': 1624147200,
#     'time': '2021-06-19 21:00',
#     'temp_c': 5.4,
#     'temp_f': 41.7,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 15,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 3,
#     'feelslike_c': 3.0,
#     'feelslike_f': 37.4,
#     'windchill_c': 3.0,
#     'windchill_f': 37.4,
#     'heatindex_c': 5.4,
#     'heatindex_f': 41.7,
#     'dewpoint_c': 2.5,
#     'dewpoint_f': 36.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 1.0},
#    {'time_epoch': 1624150800,
#     'time': '2021-06-19 22:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 12,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 2,
#     'feelslike_c': 2.9,
#     'feelslike_f': 37.2,
#     'windchill_c': 2.9,
#     'windchill_f': 37.2,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0},
#    {'time_epoch': 1624154400,
#     'time': '2021-06-19 23:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 10,
#     'wind_dir': 'N',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 1,
#     'feelslike_c': 2.9,
#     'feelslike_f': 37.2,
#     'windchill_c': 2.9,
#     'windchill_f': 37.2,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.2,
#     'dewpoint_f': 36.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0}]}]

# %%
for temperature in data['forecast']['forecastday']:
    print(f"The difference between temperatures is {round(temperature['day']['maxtemp_f'] - temperature['day']['mintemp_f'], 2)} degrees Fahrenheit.")
# Out:
# The difference between temperatures is 12.3 degrees Fahrenheit.

# %% [markdown]
# ## 4.5) How can you avoid the "oh no I don't have the data any more because I made another request" problem in the future?
#
# What variable(s) do you have to rename, and what would you rename them?

# %%
# I would have to rename response.

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
response = requests.get(f"http://api.weatherapi.com/v1/forecast.json?key={api_key_weather}&q=Cordoba&days=7&aqi=no&alerts=no")

# %%
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'Cordoba',
#   'region': 'Cordoba',
#   'country': 'Argentina',
#   'lat': -31.4,
#   'lon': -64.18,
#   'tz_id': 'America/Argentina/Cordoba',
#   'localtime_epoch': 1624215928,
#   'localtime': '2021-06-20 16:05'},
#  'current': {'last_updated_epoch': 1624212000,
#   'last_updated': '2021-06-20 15:00',
#   'temp_c': 12.0,
#   'temp_f': 53.6,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 15.0,
#   'wind_kph': 24.1,
#   'wind_degree': 40,
#   'wind_dir': 'NE',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.5,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 58,
#   'cloud': 50,
#   'feelslike_c': 9.8,
#   'feelslike_f': 49.6,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 4.0,
#   'gust_mph': 15.2,
#   'gust_kph': 24.5},
#  'forecast': {'forecastday': [{'date': '2021-06-20',
#     'date_epoch': 1624147200,
#     'day': {'maxtemp_c': 14.4,
#      'maxtemp_f': 57.9,
#      'mintemp_c': 4.3,
#      'mintemp_f': 39.7,
#      'avgtemp_c': 8.0,
#      'avgtemp_f': 46.4,
#      'maxwind_mph': 15.2,
#      'maxwind_kph': 24.5,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 70.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': '0',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 3.0},
#     'astro': {'sunrise': '08:15 AM',
#      'sunset': '06:22 PM',
#      'moonrise': '03:07 PM',
#      'moonset': '03:23 AM',
#      'moon_phase': 'Full Moon',
#      'moon_illumination': '76'},
#     'hour': [{'time_epoch': 1624158000,
#       'time': '2021-06-20 00:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 9,
#       'wind_dir': 'N',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 0,
#       'feelslike_c': 2.9,
#       'feelslike_f': 37.2,
#       'windchill_c': 2.9,
#       'windchill_f': 37.2,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.9,
#       'dewpoint_f': 35.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.2,
#       'uv': 1.0},
#      {'time_epoch': 1624161600,
#       'time': '2021-06-20 01:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 7,
#       'wind_dir': 'N',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 0,
#       'feelslike_c': 3.0,
#       'feelslike_f': 37.4,
#       'windchill_c': 3.0,
#       'windchill_f': 37.4,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.9,
#       'dewpoint_f': 35.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.4,
#       'uv': 1.0},
#      {'time_epoch': 1624165200,
#       'time': '2021-06-20 02:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 0,
#       'feelslike_c': 3.1,
#       'feelslike_f': 37.6,
#       'windchill_c': 3.1,
#       'windchill_f': 37.6,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.8,
#       'dewpoint_f': 35.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 1.0},
#      {'time_epoch': 1624168800,
#       'time': '2021-06-20 03:00',
#       'temp_c': 5.3,
#       'temp_f': 41.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 3,
#       'wind_dir': 'N',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 0,
#       'feelslike_c': 3.2,
#       'feelslike_f': 37.8,
#       'windchill_c': 3.2,
#       'windchill_f': 37.8,
#       'heatindex_c': 5.3,
#       'heatindex_f': 41.5,
#       'dewpoint_c': 1.8,
#       'dewpoint_f': 35.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 1.0},
#      {'time_epoch': 1624172400,
#       'time': '2021-06-20 04:00',
#       'temp_c': 5.0,
#       'temp_f': 41.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 0,
#       'feelslike_c': 2.9,
#       'feelslike_f': 37.2,
#       'windchill_c': 2.9,
#       'windchill_f': 37.2,
#       'heatindex_c': 5.0,
#       'heatindex_f': 41.0,
#       'dewpoint_c': 1.7,
#       'dewpoint_f': 35.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 1.0},
#      {'time_epoch': 1624176000,
#       'time': '2021-06-20 05:00',
#       'temp_c': 4.6,
#       'temp_f': 40.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 0,
#       'feelslike_c': 2.6,
#       'feelslike_f': 36.7,
#       'windchill_c': 2.6,
#       'windchill_f': 36.7,
#       'heatindex_c': 4.6,
#       'heatindex_f': 40.3,
#       'dewpoint_c': 1.7,
#       'dewpoint_f': 35.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 1.0},
#      {'time_epoch': 1624179600,
#       'time': '2021-06-20 06:00',
#       'temp_c': 4.3,
#       'temp_f': 39.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 10,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 0,
#       'feelslike_c': 2.3,
#       'feelslike_f': 36.1,
#       'windchill_c': 2.3,
#       'windchill_f': 36.1,
#       'heatindex_c': 4.3,
#       'heatindex_f': 39.7,
#       'dewpoint_c': 1.6,
#       'dewpoint_f': 34.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 1.0},
#      {'time_epoch': 1624183200,
#       'time': '2021-06-20 07:00',
#       'temp_c': 4.5,
#       'temp_f': 40.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 0,
#       'feelslike_c': 2.5,
#       'feelslike_f': 36.5,
#       'windchill_c': 2.5,
#       'windchill_f': 36.5,
#       'heatindex_c': 4.5,
#       'heatindex_f': 40.1,
#       'dewpoint_c': 1.6,
#       'dewpoint_f': 34.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0},
#      {'time_epoch': 1624186800,
#       'time': '2021-06-20 08:00',
#       'temp_c': 4.6,
#       'temp_f': 40.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 0,
#       'feelslike_c': 2.7,
#       'feelslike_f': 36.9,
#       'windchill_c': 2.7,
#       'windchill_f': 36.9,
#       'heatindex_c': 4.6,
#       'heatindex_f': 40.3,
#       'dewpoint_c': 1.5,
#       'dewpoint_f': 34.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.2,
#       'gust_kph': 14.8,
#       'uv': 1.0},
#      {'time_epoch': 1624190400,
#       'time': '2021-06-20 09:00',
#       'temp_c': 4.8,
#       'temp_f': 40.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 2,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 0,
#       'feelslike_c': 2.9,
#       'feelslike_f': 37.2,
#       'windchill_c': 2.9,
#       'windchill_f': 37.2,
#       'heatindex_c': 4.8,
#       'heatindex_f': 40.6,
#       'dewpoint_c': 1.5,
#       'dewpoint_f': 34.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 2.0},
#      {'time_epoch': 1624194000,
#       'time': '2021-06-20 10:00',
#       'temp_c': 7.1,
#       'temp_f': 44.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 11,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 8,
#       'feelslike_c': 5.1,
#       'feelslike_f': 41.2,
#       'windchill_c': 5.1,
#       'windchill_f': 41.2,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.8,
#       'dewpoint_c': 2.1,
#       'dewpoint_f': 35.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 3.0},
#      {'time_epoch': 1624197600,
#       'time': '2021-06-20 11:00',
#       'temp_c': 9.3,
#       'temp_f': 48.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 20,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 16,
#       'feelslike_c': 7.2,
#       'feelslike_f': 45.0,
#       'windchill_c': 7.2,
#       'windchill_f': 45.0,
#       'heatindex_c': 9.3,
#       'heatindex_f': 48.7,
#       'dewpoint_c': 2.7,
#       'dewpoint_f': 36.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 3.0},
#      {'time_epoch': 1624201200,
#       'time': '2021-06-20 12:00',
#       'temp_c': 11.6,
#       'temp_f': 52.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 29,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 25,
#       'feelslike_c': 9.4,
#       'feelslike_f': 48.9,
#       'windchill_c': 9.4,
#       'windchill_f': 48.9,
#       'heatindex_c': 11.6,
#       'heatindex_f': 52.9,
#       'dewpoint_c': 3.3,
#       'dewpoint_f': 37.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 4.0},
#      {'time_epoch': 1624204800,
#       'time': '2021-06-20 13:00',
#       'temp_c': 12.5,
#       'temp_f': 54.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.2,
#       'wind_kph': 21.2,
#       'wind_degree': 32,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 54,
#       'cloud': 22,
#       'feelslike_c': 10.5,
#       'feelslike_f': 50.9,
#       'windchill_c': 10.5,
#       'windchill_f': 50.9,
#       'heatindex_c': 12.5,
#       'heatindex_f': 54.5,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 4.0},
#      {'time_epoch': 1624208400,
#       'time': '2021-06-20 14:00',
#       'temp_c': 13.5,
#       'temp_f': 56.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 14.3,
#       'wind_kph': 23.0,
#       'wind_degree': 35,
#       'wind_dir': 'NE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 20,
#       'feelslike_c': 11.5,
#       'feelslike_f': 52.7,
#       'windchill_c': 11.5,
#       'windchill_f': 52.7,
#       'heatindex_c': 13.5,
#       'heatindex_f': 56.3,
#       'dewpoint_c': 3.5,
#       'dewpoint_f': 38.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.3,
#       'gust_kph': 26.3,
#       'uv': 4.0},
#      {'time_epoch': 1624212000,
#       'time': '2021-06-20 15:00',
#       'temp_c': 14.4,
#       'temp_f': 57.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.2,
#       'wind_kph': 24.5,
#       'wind_degree': 39,
#       'wind_dir': 'NE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 18,
#       'feelslike_c': 12.6,
#       'feelslike_f': 54.7,
#       'windchill_c': 12.6,
#       'windchill_f': 54.7,
#       'heatindex_c': 14.4,
#       'heatindex_f': 57.9,
#       'dewpoint_c': 3.6,
#       'dewpoint_f': 38.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 28.1,
#       'uv': 4.0},
#      {'time_epoch': 1624215600,
#       'time': '2021-06-20 16:00',
#       'temp_c': 13.2,
#       'temp_f': 55.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 14.1,
#       'wind_kph': 22.7,
#       'wind_degree': 41,
#       'wind_dir': 'NE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 19,
#       'feelslike_c': 11.3,
#       'feelslike_f': 52.3,
#       'windchill_c': 11.3,
#       'windchill_f': 52.3,
#       'heatindex_c': 13.2,
#       'heatindex_f': 55.8,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.9,
#       'gust_kph': 28.8,
#       'uv': 4.0},
#      {'time_epoch': 1624219200,
#       'time': '2021-06-20 17:00',
#       'temp_c': 12.1,
#       'temp_f': 53.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 43,
#       'wind_dir': 'NE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 55,
#       'cloud': 20,
#       'feelslike_c': 9.9,
#       'feelslike_f': 49.8,
#       'windchill_c': 9.9,
#       'windchill_f': 49.8,
#       'heatindex_c': 12.1,
#       'heatindex_f': 53.8,
#       'dewpoint_c': 3.3,
#       'dewpoint_f': 37.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.6,
#       'gust_kph': 29.9,
#       'uv': 4.0},
#      {'time_epoch': 1624222800,
#       'time': '2021-06-20 18:00',
#       'temp_c': 10.9,
#       'temp_f': 51.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 46,
#       'wind_dir': 'NE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 21,
#       'feelslike_c': 8.6,
#       'feelslike_f': 47.5,
#       'windchill_c': 8.6,
#       'windchill_f': 47.5,
#       'heatindex_c': 10.9,
#       'heatindex_f': 51.6,
#       'dewpoint_c': 3.1,
#       'dewpoint_f': 37.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.0,
#       'gust_kph': 30.6,
#       'uv': 4.0},
#      {'time_epoch': 1624226400,
#       'time': '2021-06-20 19:00',
#       'temp_c': 9.8,
#       'temp_f': 49.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 149,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 33,
#       'feelslike_c': 7.6,
#       'feelslike_f': 45.7,
#       'windchill_c': 7.6,
#       'windchill_f': 45.7,
#       'heatindex_c': 9.8,
#       'heatindex_f': 49.6,
#       'dewpoint_c': 3.2,
#       'dewpoint_f': 37.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 28.1,
#       'uv': 1.0},
#      {'time_epoch': 1624230000,
#       'time': '2021-06-20 20:00',
#       'temp_c': 8.7,
#       'temp_f': 47.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 252,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 44,
#       'feelslike_c': 6.5,
#       'feelslike_f': 43.7,
#       'windchill_c': 6.5,
#       'windchill_f': 43.7,
#       'heatindex_c': 8.7,
#       'heatindex_f': 47.7,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.1,
#       'gust_kph': 25.9,
#       'uv': 1.0},
#      {'time_epoch': 1624233600,
#       'time': '2021-06-20 21:00',
#       'temp_c': 7.6,
#       'temp_f': 45.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 356,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 56,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 7.6,
#       'heatindex_f': 45.7,
#       'dewpoint_c': 3.5,
#       'dewpoint_f': 38.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.4,
#       'uv': 1.0},
#      {'time_epoch': 1624237200,
#       'time': '2021-06-20 22:00',
#       'temp_c': 7.5,
#       'temp_f': 45.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 45,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 7.5,
#       'heatindex_f': 45.5,
#       'dewpoint_c': 3.6,
#       'dewpoint_f': 38.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.9,
#       'gust_kph': 22.3,
#       'uv': 1.0},
#      {'time_epoch': 1624240800,
#       'time': '2021-06-20 23:00',
#       'temp_c': 7.3,
#       'temp_f': 45.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 33,
#       'feelslike_c': 5.4,
#       'feelslike_f': 41.7,
#       'windchill_c': 5.4,
#       'windchill_f': 41.7,
#       'heatindex_c': 7.3,
#       'heatindex_f': 45.1,
#       'dewpoint_c': 3.7,
#       'dewpoint_f': 38.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 20.9,
#       'uv': 1.0}]},
#    {'date': '2021-06-21',
#     'date_epoch': 1624233600,
#     'day': {'maxtemp_c': 16.3,
#      'maxtemp_f': 61.3,
#      'mintemp_c': 6.8,
#      'mintemp_f': 44.2,
#      'avgtemp_c': 10.5,
#      'avgtemp_f': 50.8,
#      'maxwind_mph': 7.8,
#      'maxwind_kph': 12.6,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 70.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': '0',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 3.0},
#     'astro': {'sunrise': '08:15 AM',
#      'sunset': '06:22 PM',
#      'moonrise': '03:46 PM',
#      'moonset': '04:30 AM',
#      'moon_phase': 'Full Moon',
#      'moon_illumination': '83'},
#     'hour': [{'time_epoch': 1624244400,
#       'time': '2021-06-21 00:00',
#       'temp_c': 7.2,
#       'temp_f': 45.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 22,
#       'feelslike_c': 5.4,
#       'feelslike_f': 41.7,
#       'windchill_c': 5.4,
#       'windchill_f': 41.7,
#       'heatindex_c': 7.2,
#       'heatindex_f': 45.0,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 1.0},
#      {'time_epoch': 1624248000,
#       'time': '2021-06-21 01:00',
#       'temp_c': 7.1,
#       'temp_f': 44.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 353,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 19,
#       'feelslike_c': 5.4,
#       'feelslike_f': 41.7,
#       'windchill_c': 5.4,
#       'windchill_f': 41.7,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.8,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 1.0},
#      {'time_epoch': 1624251600,
#       'time': '2021-06-21 02:00',
#       'temp_c': 6.9,
#       'temp_f': 44.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 351,
#       'wind_dir': 'N',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 15,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 6.9,
#       'heatindex_f': 44.4,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.1,
#       'gust_kph': 16.2,
#       'uv': 1.0},
#      {'time_epoch': 1624255200,
#       'time': '2021-06-21 03:00',
#       'temp_c': 6.8,
#       'temp_f': 44.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 350,
#       'wind_dir': 'N',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 11,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 6.8,
#       'heatindex_f': 44.2,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 1.0},
#      {'time_epoch': 1624258800,
#       'time': '2021-06-21 04:00',
#       'temp_c': 6.8,
#       'temp_f': 44.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 347,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 9,
#       'feelslike_c': 5.7,
#       'feelslike_f': 42.3,
#       'windchill_c': 5.7,
#       'windchill_f': 42.3,
#       'heatindex_c': 6.8,
#       'heatindex_f': 44.2,
#       'dewpoint_c': 3.9,
#       'dewpoint_f': 39.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 1.0},
#      {'time_epoch': 1624262400,
#       'time': '2021-06-21 05:00',
#       'temp_c': 6.9,
#       'temp_f': 44.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 345,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 6,
#       'feelslike_c': 6.0,
#       'feelslike_f': 42.8,
#       'windchill_c': 6.0,
#       'windchill_f': 42.8,
#       'heatindex_c': 6.9,
#       'heatindex_f': 44.4,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.4,
#       'gust_kph': 11.9,
#       'uv': 1.0},
#      {'time_epoch': 1624266000,
#       'time': '2021-06-21 06:00',
#       'temp_c': 6.9,
#       'temp_f': 44.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 343,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 4,
#       'feelslike_c': 6.2,
#       'feelslike_f': 43.2,
#       'windchill_c': 6.2,
#       'windchill_f': 43.2,
#       'heatindex_c': 6.9,
#       'heatindex_f': 44.4,
#       'dewpoint_c': 4.1,
#       'dewpoint_f': 39.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 1.0},
#      {'time_epoch': 1624269600,
#       'time': '2021-06-21 07:00',
#       'temp_c': 7.2,
#       'temp_f': 45.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 304,
#       'wind_dir': 'NW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 3,
#       'feelslike_c': 6.8,
#       'feelslike_f': 44.2,
#       'windchill_c': 6.8,
#       'windchill_f': 44.2,
#       'heatindex_c': 7.2,
#       'heatindex_f': 45.0,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 1.0},
#      {'time_epoch': 1624273200,
#       'time': '2021-06-21 08:00',
#       'temp_c': 7.6,
#       'temp_f': 45.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 266,
#       'wind_dir': 'W',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 2,
#       'feelslike_c': 7.5,
#       'feelslike_f': 45.5,
#       'windchill_c': 7.5,
#       'windchill_f': 45.5,
#       'heatindex_c': 7.6,
#       'heatindex_f': 45.7,
#       'dewpoint_c': 4.8,
#       'dewpoint_f': 40.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 1.0},
#      {'time_epoch': 1624276800,
#       'time': '2021-06-21 09:00',
#       'temp_c': 7.9,
#       'temp_f': 46.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 2,
#       'feelslike_c': 8.1,
#       'feelslike_f': 46.6,
#       'windchill_c': 8.1,
#       'windchill_f': 46.6,
#       'heatindex_c': 7.9,
#       'heatindex_f': 46.2,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.9,
#       'gust_kph': 4.7,
#       'uv': 3.0},
#      {'time_epoch': 1624280400,
#       'time': '2021-06-21 10:00',
#       'temp_c': 9.9,
#       'temp_f': 49.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 181,
#       'wind_dir': 'S',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 1,
#       'feelslike_c': 10.3,
#       'feelslike_f': 50.5,
#       'windchill_c': 10.3,
#       'windchill_f': 50.5,
#       'heatindex_c': 9.9,
#       'heatindex_f': 49.8,
#       'dewpoint_c': 5.3,
#       'dewpoint_f': 41.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.7,
#       'gust_kph': 4.3,
#       'uv': 3.0},
#      {'time_epoch': 1624284000,
#       'time': '2021-06-21 11:00',
#       'temp_c': 11.9,
#       'temp_f': 53.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 134,
#       'wind_dir': 'SE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 66,
#       'cloud': 1,
#       'feelslike_c': 12.4,
#       'feelslike_f': 54.3,
#       'windchill_c': 12.4,
#       'windchill_f': 54.3,
#       'heatindex_c': 11.9,
#       'heatindex_f': 53.4,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 41.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.7,
#       'gust_kph': 4.3,
#       'uv': 4.0},
#      {'time_epoch': 1624287600,
#       'time': '2021-06-21 12:00',
#       'temp_c': 13.9,
#       'temp_f': 57.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 87,
#       'wind_dir': 'E',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 58,
#       'cloud': 0,
#       'feelslike_c': 14.6,
#       'feelslike_f': 58.3,
#       'windchill_c': 14.6,
#       'windchill_f': 58.3,
#       'heatindex_c': 13.9,
#       'heatindex_f': 57.0,
#       'dewpoint_c': 5.7,
#       'dewpoint_f': 42.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.5,
#       'gust_kph': 4.0,
#       'uv': 4.0},
#      {'time_epoch': 1624291200,
#       'time': '2021-06-21 13:00',
#       'temp_c': 14.7,
#       'temp_f': 58.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 82,
#       'wind_dir': 'E',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 53,
#       'cloud': 1,
#       'feelslike_c': 15.2,
#       'feelslike_f': 59.4,
#       'windchill_c': 15.2,
#       'windchill_f': 59.4,
#       'heatindex_c': 14.7,
#       'heatindex_f': 58.5,
#       'dewpoint_c': 5.2,
#       'dewpoint_f': 41.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 4.0},
#      {'time_epoch': 1624294800,
#       'time': '2021-06-21 14:00',
#       'temp_c': 15.5,
#       'temp_f': 59.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 76,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 2,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.3,
#       'windchill_c': 15.7,
#       'windchill_f': 60.3,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.9,
#       'dewpoint_c': 4.7,
#       'dewpoint_f': 40.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.9,
#       'uv': 5.0},
#      {'time_epoch': 1624298400,
#       'time': '2021-06-21 15:00',
#       'temp_c': 16.3,
#       'temp_f': 61.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 70,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 44,
#       'cloud': 3,
#       'feelslike_c': 16.3,
#       'feelslike_f': 61.3,
#       'windchill_c': 16.3,
#       'windchill_f': 61.3,
#       'heatindex_c': 16.3,
#       'heatindex_f': 61.3,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.3,
#       'gust_kph': 10.1,
#       'uv': 5.0},
#      {'time_epoch': 1624302000,
#       'time': '2021-06-21 16:00',
#       'temp_c': 15.5,
#       'temp_f': 59.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 70,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 5,
#       'feelslike_c': 15.2,
#       'feelslike_f': 59.4,
#       'windchill_c': 15.2,
#       'windchill_f': 59.4,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.9,
#       'dewpoint_c': 4.5,
#       'dewpoint_f': 40.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.7,
#       'uv': 5.0},
#      {'time_epoch': 1624305600,
#       'time': '2021-06-21 17:00',
#       'temp_c': 14.8,
#       'temp_f': 58.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 70,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 7,
#       'feelslike_c': 14.2,
#       'feelslike_f': 57.6,
#       'windchill_c': 14.2,
#       'windchill_f': 57.6,
#       'heatindex_c': 14.8,
#       'heatindex_f': 58.6,
#       'dewpoint_c': 4.8,
#       'dewpoint_f': 40.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 4.0},
#      {'time_epoch': 1624309200,
#       'time': '2021-06-21 18:00',
#       'temp_c': 14.0,
#       'temp_f': 57.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 70,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 55,
#       'cloud': 10,
#       'feelslike_c': 13.1,
#       'feelslike_f': 55.6,
#       'windchill_c': 13.1,
#       'windchill_f': 55.6,
#       'heatindex_c': 14.0,
#       'heatindex_f': 57.2,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.8,
#       'gust_kph': 20.5,
#       'uv': 4.0},
#      {'time_epoch': 1624312800,
#       'time': '2021-06-21 19:00',
#       'temp_c': 12.9,
#       'temp_f': 55.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 165,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 6,
#       'feelslike_c': 11.8,
#       'feelslike_f': 53.2,
#       'windchill_c': 11.8,
#       'windchill_f': 53.2,
#       'heatindex_c': 12.9,
#       'heatindex_f': 55.2,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.2,
#       'uv': 1.0},
#      {'time_epoch': 1624316400,
#       'time': '2021-06-21 20:00',
#       'temp_c': 11.7,
#       'temp_f': 53.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 260,
#       'wind_dir': 'W',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 3,
#       'feelslike_c': 10.6,
#       'feelslike_f': 51.1,
#       'windchill_c': 10.6,
#       'windchill_f': 51.1,
#       'heatindex_c': 11.7,
#       'heatindex_f': 53.1,
#       'dewpoint_c': 6.0,
#       'dewpoint_f': 42.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.4,
#       'uv': 1.0},
#      {'time_epoch': 1624320000,
#       'time': '2021-06-21 21:00',
#       'temp_c': 10.6,
#       'temp_f': 51.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 356,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 0,
#       'feelslike_c': 9.3,
#       'feelslike_f': 48.7,
#       'windchill_c': 9.3,
#       'windchill_f': 48.7,
#       'heatindex_c': 10.6,
#       'heatindex_f': 51.1,
#       'dewpoint_c': 6.5,
#       'dewpoint_f': 43.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 1.0},
#      {'time_epoch': 1624323600,
#       'time': '2021-06-21 22:00',
#       'temp_c': 10.6,
#       'temp_f': 51.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 239,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 0,
#       'feelslike_c': 9.5,
#       'feelslike_f': 49.1,
#       'windchill_c': 9.5,
#       'windchill_f': 49.1,
#       'heatindex_c': 10.6,
#       'heatindex_f': 51.1,
#       'dewpoint_c': 6.9,
#       'dewpoint_f': 44.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 1.0},
#      {'time_epoch': 1624327200,
#       'time': '2021-06-21 23:00',
#       'temp_c': 10.7,
#       'temp_f': 51.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 121,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 0,
#       'feelslike_c': 9.7,
#       'feelslike_f': 49.5,
#       'windchill_c': 9.7,
#       'windchill_f': 49.5,
#       'heatindex_c': 10.7,
#       'heatindex_f': 51.3,
#       'dewpoint_c': 7.3,
#       'dewpoint_f': 45.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.0,
#       'uv': 1.0}]},
#    {'date': '2021-06-22',
#     'date_epoch': 1624320000,
#     'day': {'maxtemp_c': 16.4,
#      'maxtemp_f': 61.5,
#      'mintemp_c': 7.4,
#      'mintemp_f': 45.3,
#      'avgtemp_c': 11.7,
#      'avgtemp_f': 53.1,
#      'maxwind_mph': 15.9,
#      'maxwind_kph': 25.6,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 74.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': '0',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 3.0},
#     'astro': {'sunrise': '08:16 AM',
#      'sunset': '06:22 PM',
#      'moonrise': '04:29 PM',
#      'moonset': '05:42 AM',
#      'moon_phase': 'Full Moon',
# ...
#       'vis_miles': 6.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.4,
#       'uv': 1.0},
#      {'time_epoch': 1624356000,
#       'time': '2021-06-22 07:00',
#       'temp_c': 7.4,
#       'temp_f': 45.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 11,
#       'feelslike_c': 5.3,
#       'feelslike_f': 41.5,
#       'windchill_c': 5.3,
#       'windchill_f': 41.5,
#       'heatindex_c': 7.4,
#       'heatindex_f': 45.3,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.3,
#       'gust_kph': 23.0,
#       'uv': 1.0},
#      {'time_epoch': 1624359600,
#       'time': '2021-06-22 08:00',
#       'temp_c': 7.5,
#       'temp_f': 45.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 12,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 14,
#       'feelslike_c': 5.4,
#       'feelslike_f': 41.7,
#       'windchill_c': 5.4,
#       'windchill_f': 41.7,
#       'heatindex_c': 7.5,
#       'heatindex_f': 45.5,
#       'dewpoint_c': 5.7,
#       'dewpoint_f': 42.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.3,
#       'gust_kph': 23.0,
#       'uv': 1.0},
#      {'time_epoch': 1624363200,
#       'time': '2021-06-22 09:00',
#       'temp_c': 7.5,
#       'temp_f': 45.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 16,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 18,
#       'feelslike_c': 5.4,
#       'feelslike_f': 41.7,
#       'windchill_c': 5.4,
#       'windchill_f': 41.7,
#       'heatindex_c': 7.5,
#       'heatindex_f': 45.5,
#       'dewpoint_c': 5.8,
#       'dewpoint_f': 42.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 3.0},
#      {'time_epoch': 1624366800,
#       'time': '2021-06-22 10:00',
#       'temp_c': 9.7,
#       'temp_f': 49.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 20,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 20,
#       'feelslike_c': 7.7,
#       'feelslike_f': 45.9,
#       'windchill_c': 7.7,
#       'windchill_f': 45.9,
#       'heatindex_c': 9.7,
#       'heatindex_f': 49.5,
#       'dewpoint_c': 6.5,
#       'dewpoint_f': 43.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 3.0},
#      {'time_epoch': 1624370400,
#       'time': '2021-06-22 11:00',
#       'temp_c': 12.0,
#       'temp_f': 53.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 23,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 21,
#       'feelslike_c': 10.1,
#       'feelslike_f': 50.2,
#       'windchill_c': 10.1,
#       'windchill_f': 50.2,
#       'heatindex_c': 12.0,
#       'heatindex_f': 53.6,
#       'dewpoint_c': 7.3,
#       'dewpoint_f': 45.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.1,
#       'gust_kph': 25.9,
#       'uv': 4.0},
#      {'time_epoch': 1624374000,
#       'time': '2021-06-22 12:00',
#       'temp_c': 14.2,
#       'temp_f': 57.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 27,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 66,
#       'cloud': 23,
#       'feelslike_c': 12.4,
#       'feelslike_f': 54.3,
#       'windchill_c': 12.4,
#       'windchill_f': 54.3,
#       'heatindex_c': 14.2,
#       'heatindex_f': 57.6,
#       'dewpoint_c': 8.0,
#       'dewpoint_f': 46.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.2,
#       'gust_kph': 27.7,
#       'uv': 4.0},
#      {'time_epoch': 1624377600,
#       'time': '2021-06-22 13:00',
#       'temp_c': 14.9,
#       'temp_f': 58.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.2,
#       'wind_kph': 24.5,
#       'wind_degree': 28,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 34,
#       'feelslike_c': 13.7,
#       'feelslike_f': 56.7,
#       'windchill_c': 13.7,
#       'windchill_f': 56.7,
#       'heatindex_c': 14.9,
#       'heatindex_f': 58.8,
#       'dewpoint_c': 7.9,
#       'dewpoint_f': 46.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.7,
#       'gust_kph': 28.4,
#       'uv': 4.0},
#      {'time_epoch': 1624381200,
#       'time': '2021-06-22 14:00',
#       'temp_c': 15.7,
#       'temp_f': 60.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 28,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 60,
#       'cloud': 44,
#       'feelslike_c': 15.1,
#       'feelslike_f': 59.2,
#       'windchill_c': 15.1,
#       'windchill_f': 59.2,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.3,
#       'dewpoint_c': 7.9,
#       'dewpoint_f': 46.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.9,
#       'gust_kph': 28.8,
#       'uv': 5.0},
#      {'time_epoch': 1624384800,
#       'time': '2021-06-22 15:00',
#       'temp_c': 16.4,
#       'temp_f': 61.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.9,
#       'wind_kph': 25.6,
#       'wind_degree': 29,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 55,
#       'feelslike_c': 16.4,
#       'feelslike_f': 61.5,
#       'windchill_c': 16.4,
#       'windchill_f': 61.5,
#       'heatindex_c': 16.4,
#       'heatindex_f': 61.5,
#       'dewpoint_c': 7.8,
#       'dewpoint_f': 46.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.3,
#       'gust_kph': 29.5,
#       'uv': 5.0},
#      {'time_epoch': 1624388400,
#       'time': '2021-06-22 16:00',
#       'temp_c': 15.8,
#       'temp_f': 60.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 28,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 58,
#       'cloud': 55,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.5,
#       'windchill_c': 15.3,
#       'windchill_f': 59.5,
#       'heatindex_c': 15.8,
#       'heatindex_f': 60.4,
#       'dewpoint_c': 7.5,
#       'dewpoint_f': 45.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.1,
#       'gust_kph': 29.2,
#       'uv': 5.0},
#      {'time_epoch': 1624392000,
#       'time': '2021-06-22 17:00',
#       'temp_c': 15.3,
#       'temp_f': 59.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.9,
#       'wind_kph': 22.3,
#       'wind_degree': 26,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 55,
#       'feelslike_c': 14.3,
#       'feelslike_f': 57.7,
#       'windchill_c': 14.3,
#       'windchill_f': 57.7,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.5,
#       'dewpoint_c': 7.3,
#       'dewpoint_f': 45.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.9,
#       'gust_kph': 28.8,
#       'uv': 5.0},
#      {'time_epoch': 1624395600,
#       'time': '2021-06-22 18:00',
#       'temp_c': 14.7,
#       'temp_f': 58.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 24,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 60,
#       'cloud': 54,
#       'feelslike_c': 13.2,
#       'feelslike_f': 55.8,
#       'windchill_c': 13.2,
#       'windchill_f': 55.8,
#       'heatindex_c': 14.7,
#       'heatindex_f': 58.5,
#       'dewpoint_c': 7.0,
#       'dewpoint_f': 44.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.7,
#       'gust_kph': 28.4,
#       'uv': 4.0},
#      {'time_epoch': 1624399200,
#       'time': '2021-06-22 19:00',
#       'temp_c': 14.5,
#       'temp_f': 58.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 31,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 61,
#       'cloud': 70,
#       'feelslike_c': 13.0,
#       'feelslike_f': 55.4,
#       'windchill_c': 13.0,
#       'windchill_f': 55.4,
#       'heatindex_c': 14.5,
#       'heatindex_f': 58.1,
#       'dewpoint_c': 7.0,
#       'dewpoint_f': 44.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.4,
#       'uv': 1.0},
#      {'time_epoch': 1624402800,
#       'time': '2021-06-22 20:00',
#       'temp_c': 14.3,
#       'temp_f': 57.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 38,
#       'wind_dir': 'NE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 85,
#       'feelslike_c': 12.9,
#       'feelslike_f': 55.2,
#       'windchill_c': 12.9,
#       'windchill_f': 55.2,
#       'heatindex_c': 14.3,
#       'heatindex_f': 57.7,
#       'dewpoint_c': 7.1,
#       'dewpoint_f': 44.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.1,
#       'gust_kph': 25.9,
#       'uv': 1.0},
#      {'time_epoch': 1624406400,
#       'time': '2021-06-22 21:00',
#       'temp_c': 14.1,
#       'temp_f': 57.4,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 44,
#       'wind_dir': 'NE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 100,
#       'feelslike_c': 12.7,
#       'feelslike_f': 54.9,
#       'windchill_c': 12.7,
#       'windchill_f': 54.9,
#       'heatindex_c': 14.1,
#       'heatindex_f': 57.4,
#       'dewpoint_c': 7.1,
#       'dewpoint_f': 44.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 1.0},
#      {'time_epoch': 1624410000,
#       'time': '2021-06-22 22:00',
#       'temp_c': 13.8,
#       'temp_f': 56.8,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 11.0,
#       'wind_kph': 17.6,
#       'wind_degree': 38,
#       'wind_dir': 'NE',
#       'pressure_mb': 1012.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 91,
#       'feelslike_c': 12.4,
#       'feelslike_f': 54.3,
#       'windchill_c': 12.4,
#       'windchill_f': 54.3,
#       'heatindex_c': 13.8,
#       'heatindex_f': 56.8,
#       'dewpoint_c': 7.3,
#       'dewpoint_f': 45.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.8,
#       'gust_kph': 23.8,
#       'uv': 1.0},
#      {'time_epoch': 1624413600,
#       'time': '2021-06-22 23:00',
#       'temp_c': 13.5,
#       'temp_f': 56.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 32,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1012.0,
#       'pressure_in': 30.4,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 82,
#       'feelslike_c': 12.0,
#       'feelslike_f': 53.6,
#       'windchill_c': 12.0,
#       'windchill_f': 53.6,
#       'heatindex_c': 13.5,
#       'heatindex_f': 56.3,
#       'dewpoint_c': 7.5,
#       'dewpoint_f': 45.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 1.0}]}]}}

# %%
data['forecast']['forecastday']
# Out:
# [{'date': '2021-06-19',
#   'date_epoch': 1624060800,
#   'day': {'maxtemp_c': 10.7,
#    'maxtemp_f': 51.3,
#    'mintemp_c': 3.9,
#    'mintemp_f': 39.0,
#    'avgtemp_c': 6.7,
#    'avgtemp_f': 44.0,
#    'maxwind_mph': 8.9,
#    'maxwind_kph': 14.4,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 74.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'uv': 3.0},
#   'astro': {'sunrise': '08:15 AM',
#    'sunset': '06:21 PM',
#    'moonrise': '02:32 PM',
#    'moonset': '02:17 AM',
#    'moon_phase': 'Waxing Gibbous',
#    'moon_illumination': '69'},
#   'hour': [{'time_epoch': 1624071600,
#     'time': '2021-06-19 00:00',
#     'temp_c': 5.7,
#     'temp_f': 42.3,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 10,
#     'wind_dir': 'N',
#     'pressure_mb': 1028.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 100,
#     'feelslike_c': 4.4,
#     'feelslike_f': 39.9,
#     'windchill_c': 4.4,
#     'windchill_f': 39.9,
#     'heatindex_c': 5.7,
#     'heatindex_f': 42.3,
#     'dewpoint_c': 1.6,
#     'dewpoint_f': 34.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.3,
#     'gust_kph': 10.1,
#     'uv': 1.0},
#    {'time_epoch': 1624075200,
#     'time': '2021-06-19 01:00',
#     'temp_c': 5.6,
#     'temp_f': 42.1,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 12,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 93,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.7,
#     'windchill_c': 4.3,
#     'windchill_f': 39.7,
#     'heatindex_c': 5.6,
#     'heatindex_f': 42.1,
#     'dewpoint_c': 1.6,
#     'dewpoint_f': 34.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 1.0},
#    {'time_epoch': 1624078800,
#     'time': '2021-06-19 02:00',
#     'temp_c': 5.6,
#     'temp_f': 42.1,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 13,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 86,
#     'feelslike_c': 4.1,
#     'feelslike_f': 39.4,
#     'windchill_c': 4.1,
#     'windchill_f': 39.4,
#     'heatindex_c': 5.6,
#     'heatindex_f': 42.1,
#     'dewpoint_c': 1.5,
#     'dewpoint_f': 34.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 1.0},
#    {'time_epoch': 1624082400,
#     'time': '2021-06-19 03:00',
#     'temp_c': 5.5,
#     'temp_f': 41.9,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 15,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 80,
#     'feelslike_c': 4.0,
#     'feelslike_f': 39.2,
#     'windchill_c': 4.0,
#     'windchill_f': 39.2,
#     'heatindex_c': 5.5,
#     'heatindex_f': 41.9,
#     'dewpoint_c': 1.5,
#     'dewpoint_f': 34.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624086000,
#     'time': '2021-06-19 04:00',
#     'temp_c': 5.0,
#     'temp_f': 41.0,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 17,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 84,
#     'feelslike_c': 3.5,
#     'feelslike_f': 38.3,
#     'windchill_c': 3.5,
#     'windchill_f': 38.3,
#     'heatindex_c': 5.0,
#     'heatindex_f': 41.0,
#     'dewpoint_c': 1.7,
#     'dewpoint_f': 35.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624089600,
#     'time': '2021-06-19 05:00',
#     'temp_c': 4.4,
#     'temp_f': 39.9,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 18,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 83,
#     'cloud': 89,
#     'feelslike_c': 2.9,
#     'feelslike_f': 37.2,
#     'windchill_c': 2.9,
#     'windchill_f': 37.2,
#     'heatindex_c': 4.4,
#     'heatindex_f': 39.9,
#     'dewpoint_c': 1.8,
#     'dewpoint_f': 35.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624093200,
#     'time': '2021-06-19 06:00',
#     'temp_c': 3.9,
#     'temp_f': 39.0,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 20,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 93,
#     'feelslike_c': 2.4,
#     'feelslike_f': 36.3,
#     'windchill_c': 2.4,
#     'windchill_f': 36.3,
#     'heatindex_c': 3.9,
#     'heatindex_f': 39.0,
#     'dewpoint_c': 2.0,
#     'dewpoint_f': 35.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0},
#    {'time_epoch': 1624096800,
#     'time': '2021-06-19 07:00',
#     'temp_c': 4.4,
#     'temp_f': 39.9,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 22,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 86,
#     'feelslike_c': 3.0,
#     'feelslike_f': 37.4,
#     'windchill_c': 3.0,
#     'windchill_f': 37.4,
#     'heatindex_c': 4.4,
#     'heatindex_f': 39.9,
#     'dewpoint_c': 2.1,
#     'dewpoint_f': 35.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.0,
#     'gust_kph': 9.7,
#     'uv': 1.0},
#    {'time_epoch': 1624100400,
#     'time': '2021-06-19 08:00',
#     'temp_c': 4.8,
#     'temp_f': 40.6,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 24,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 83,
#     'cloud': 80,
#     'feelslike_c': 3.7,
#     'feelslike_f': 38.7,
#     'windchill_c': 3.7,
#     'windchill_f': 38.7,
#     'heatindex_c': 4.8,
#     'heatindex_f': 40.6,
#     'dewpoint_c': 2.1,
#     'dewpoint_f': 35.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.6,
#     'gust_kph': 9.0,
#     'uv': 1.0},
#    {'time_epoch': 1624104000,
#     'time': '2021-06-19 09:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 26,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1028.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 73,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.7,
#     'windchill_c': 4.3,
#     'windchill_f': 39.7,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.2,
#     'dewpoint_f': 36.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.9,
#     'gust_kph': 7.9,
#     'uv': 2.0},
#    {'time_epoch': 1624107600,
#     'time': '2021-06-19 10:00',
#     'temp_c': 6.4,
#     'temp_f': 43.5,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 30,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 62,
#     'feelslike_c': 5.1,
#     'feelslike_f': 41.2,
#     'windchill_c': 5.1,
#     'windchill_f': 41.2,
#     'heatindex_c': 6.4,
#     'heatindex_f': 43.5,
#     'dewpoint_c': 2.5,
#     'dewpoint_f': 36.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.8,
#     'gust_kph': 9.4,
#     'uv': 3.0},
#    {'time_epoch': 1624111200,
#     'time': '2021-06-19 11:00',
#     'temp_c': 7.4,
#     'temp_f': 45.3,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 35,
#     'wind_dir': 'NE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 51,
#     'feelslike_c': 6.0,
#     'feelslike_f': 42.8,
#     'windchill_c': 6.0,
#     'windchill_f': 42.8,
#     'heatindex_c': 7.4,
#     'heatindex_f': 45.3,
#     'dewpoint_c': 2.8,
#     'dewpoint_f': 37.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 2.0},
#    {'time_epoch': 1624114800,
#     'time': '2021-06-19 12:00',
#     'temp_c': 8.5,
#     'temp_f': 47.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 39,
#     'wind_dir': 'NE',
#     'pressure_mb': 1027.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 69,
#     'cloud': 39,
#     'feelslike_c': 6.8,
#     'feelslike_f': 44.2,
#     'windchill_c': 6.8,
#     'windchill_f': 44.2,
#     'heatindex_c': 8.5,
#     'heatindex_f': 47.3,
#     'dewpoint_c': 3.1,
#     'dewpoint_f': 37.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 3.0},
#    {'time_epoch': 1624118400,
#     'time': '2021-06-19 13:00',
#     'temp_c': 9.2,
#     'temp_f': 48.6,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 7.4,
#     'wind_kph': 11.9,
#     'wind_degree': 42,
#     'wind_dir': 'NE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 65,
#     'cloud': 45,
#     'feelslike_c': 7.5,
#     'feelslike_f': 45.5,
#     'windchill_c': 7.5,
#     'windchill_f': 45.5,
#     'heatindex_c': 9.2,
#     'heatindex_f': 48.6,
#     'dewpoint_c': 2.9,
#     'dewpoint_f': 37.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.3,
#     'gust_kph': 13.3,
#     'uv': 3.0},
#    {'time_epoch': 1624122000,
#     'time': '2021-06-19 14:00',
#     'temp_c': 10.0,
#     'temp_f': 50.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.1,
#     'wind_kph': 13.0,
#     'wind_degree': 46,
#     'wind_dir': 'NE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 61,
#     'cloud': 50,
#     'feelslike_c': 8.1,
#     'feelslike_f': 46.6,
#     'windchill_c': 8.1,
#     'windchill_f': 46.6,
#     'heatindex_c': 10.0,
#     'heatindex_f': 50.0,
#     'dewpoint_c': 2.7,
#     'dewpoint_f': 36.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 4.0},
#    {'time_epoch': 1624125600,
#     'time': '2021-06-19 15:00',
#     'temp_c': 10.7,
#     'temp_f': 51.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.9,
#     'wind_kph': 14.4,
#     'wind_degree': 49,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 57,
#     'cloud': 56,
#     'feelslike_c': 8.8,
#     'feelslike_f': 47.8,
#     'windchill_c': 8.8,
#     'windchill_f': 47.8,
#     'heatindex_c': 10.7,
#     'heatindex_f': 51.3,
#     'dewpoint_c': 2.5,
#     'dewpoint_f': 36.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.3,
#     'gust_kph': 16.6,
#     'uv': 4.0},
#    {'time_epoch': 1624129200,
#     'time': '2021-06-19 16:00',
#     'temp_c': 9.9,
#     'temp_f': 49.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.7,
#     'wind_kph': 14.0,
#     'wind_degree': 50,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 60,
#     'cloud': 52,
#     'feelslike_c': 7.9,
#     'feelslike_f': 46.2,
#     'windchill_c': 7.9,
#     'windchill_f': 46.2,
#     'heatindex_c': 9.9,
#     'heatindex_f': 49.8,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.0,
#     'gust_kph': 17.6,
#     'uv': 3.0},
#    {'time_epoch': 1624132800,
#     'time': '2021-06-19 17:00',
#     'temp_c': 9.1,
#     'temp_f': 48.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.3,
#     'wind_kph': 13.3,
#     'wind_degree': 51,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 63,
#     'cloud': 47,
#     'feelslike_c': 7.0,
#     'feelslike_f': 44.6,
#     'windchill_c': 7.0,
#     'windchill_f': 44.6,
#     'heatindex_c': 9.1,
#     'heatindex_f': 48.4,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 3.0},
#    {'time_epoch': 1624136400,
#     'time': '2021-06-19 18:00',
#     'temp_c': 8.3,
#     'temp_f': 46.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.1,
#     'wind_kph': 13.0,
#     'wind_degree': 51,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 66,
#     'cloud': 43,
#     'feelslike_c': 6.1,
#     'feelslike_f': 43.0,
#     'windchill_c': 6.1,
#     'windchill_f': 43.0,
#     'heatindex_c': 8.3,
#     'heatindex_f': 46.9,
#     'dewpoint_c': 2.3,
#     'dewpoint_f': 36.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 3.0},
#    {'time_epoch': 1624140000,
#     'time': '2021-06-19 19:00',
#     'temp_c': 7.3,
#     'temp_f': 45.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.6,
#     'wind_kph': 12.2,
#     'wind_degree': 39,
#     'wind_dir': 'NE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 71,
#     'cloud': 30,
#     'feelslike_c': 5.1,
#     'feelslike_f': 41.2,
#     'windchill_c': 5.1,
#     'windchill_f': 41.2,
#     'heatindex_c': 7.3,
#     'heatindex_f': 45.1,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0},
#    {'time_epoch': 1624143600,
#     'time': '2021-06-19 20:00',
#     'temp_c': 6.4,
#     'temp_f': 43.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 27,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 16,
#     'feelslike_c': 4.0,
#     'feelslike_f': 39.2,
#     'windchill_c': 4.0,
#     'windchill_f': 39.2,
#     'heatindex_c': 6.4,
#     'heatindex_f': 43.5,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 1.0},
#    {'time_epoch': 1624147200,
#     'time': '2021-06-19 21:00',
#     'temp_c': 5.4,
#     'temp_f': 41.7,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 15,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 3,
#     'feelslike_c': 3.0,
#     'feelslike_f': 37.4,
#     'windchill_c': 3.0,
#     'windchill_f': 37.4,
#     'heatindex_c': 5.4,
#     'heatindex_f': 41.7,
#     'dewpoint_c': 2.5,
#     'dewpoint_f': 36.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 1.0},
#    {'time_epoch': 1624150800,
#     'time': '2021-06-19 22:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 12,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 2,
#     'feelslike_c': 2.9,
#     'feelslike_f': 37.2,
#     'windchill_c': 2.9,
#     'windchill_f': 37.2,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0},
#    {'time_epoch': 1624154400,
#     'time': '2021-06-19 23:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 10,
#     'wind_dir': 'N',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 1,
#     'feelslike_c': 2.9,
#     'feelslike_f': 37.2,
#     'windchill_c': 2.9,
#     'windchill_f': 37.2,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.2,
#     'dewpoint_f': 36.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0}]},
#  {'date': '2021-06-20',
#   'date_epoch': 1624147200,
#   'day': {'maxtemp_c': 13.9,
#    'maxtemp_f': 57.0,
#    'mintemp_c': 4.6,
#    'mintemp_f': 40.3,
#    'avgtemp_c': 7.9,
#    'avgtemp_f': 46.2,
#    'maxwind_mph': 15.0,
#    'maxwind_kph': 24.1,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 72.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'uv': 3.0},
#   'astro': {'sunrise': '08:15 AM',
#    'sunset': '06:22 PM',
#    'moonrise': '03:07 PM',
#    'moonset': '03:23 AM',
#    'moon_phase': 'Full Moon',
#    'moon_illumination': '76'},
#   'hour': [{'time_epoch': 1624158000,
#     'time': '2021-06-20 00:00',
#     'temp_c': 5.2,
#     'temp_f': 41.4,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 7,
#     'wind_dir': 'N',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 0,
#     'feelslike_c': 2.8,
#     'feelslike_f': 37.0,
#     'windchill_c': 2.8,
#     'windchill_f': 37.0,
#     'heatindex_c': 5.2,
#     'heatindex_f': 41.4,
#     'dewpoint_c': 2.1,
#     'dewpoint_f': 35.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.5,
#     'gust_kph': 20.2,
#     'uv': 1.0},
#    {'time_epoch': 1624161600,
#     'time': '2021-06-20 01:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 124,
#     'wind_dir': 'SE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 0,
#     'feelslike_c': 3.0,
#     'feelslike_f': 37.4,
#     'windchill_c': 3.0,
#     'windchill_f': 37.4,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.1,
#     'dewpoint_f': 35.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0},
#    {'time_epoch': 1624165200,
#     'time': '2021-06-20 02:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 241,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 0,
#     'feelslike_c': 3.1,
#     'feelslike_f': 37.6,
#     'windchill_c': 3.1,
#     'windchill_f': 37.6,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 2.0,
#     'dewpoint_f': 35.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 1.0},
#    {'time_epoch': 1624168800,
#     'time': '2021-06-20 03:00',
#     'temp_c': 5.4,
#     'temp_f': 41.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 5.8,
#     'wind_kph': 9.4,
#     'wind_degree': 358,
#     'wind_dir': 'N',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 0,
#     'feelslike_c': 3.3,
#     'feelslike_f': 37.9,
#     'windchill_c': 3.3,
#     'windchill_f': 37.9,
#     'heatindex_c': 5.4,
#     'heatindex_f': 41.7,
#     'dewpoint_c': 2.0,
#     'dewpoint_f': 35.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 1.0},
#    {'time_epoch': 1624172400,
#     'time': '2021-06-20 04:00',
#     'temp_c': 5.2,
#     'temp_f': 41.4,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 5.8,
#     'wind_kph': 9.4,
#     'wind_degree': 242,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 0,
#     'feelslike_c': 3.0,
#     'feelslike_f': 37.4,
#     'windchill_c': 3.0,
#     'windchill_f': 37.4,
#     'heatindex_c': 5.2,
#     'heatindex_f': 41.4,
#     'dewpoint_c': 1.9,
#     'dewpoint_f': 35.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 1.0},
#    {'time_epoch': 1624176000,
#     'time': '2021-06-20 05:00',
#     'temp_c': 4.9,
#     'temp_f': 40.8,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 127,
#     'wind_dir': 'SE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 0,
#     'feelslike_c': 2.8,
#     'feelslike_f': 37.0,
#     'windchill_c': 2.8,
#     'windchill_f': 37.0,
#     'heatindex_c': 4.9,
#     'heatindex_f': 40.8,
#     'dewpoint_c': 1.9,
#     'dewpoint_f': 35.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 1.0},
#    {'time_epoch': 1624179600,
#     'time': '2021-06-20 06:00',
#     'temp_c': 4.7,
#     'temp_f': 40.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 11,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 0,
#     'feelslike_c': 2.5,
#     'feelslike_f': 36.5,
#     'windchill_c': 2.5,
#     'windchill_f': 36.5,
#     'heatindex_c': 4.7,
#     'heatindex_f': 40.5,
#     'dewpoint_c': 1.8,
#     'dewpoint_f': 35.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.0,
#     'gust_kph': 17.6,
#     'uv': 1.0},
#    {'time_epoch': 1624183200,
#     'time': '2021-06-20 07:00',
#     'temp_c': 4.7,
#     'temp_f': 40.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 5.8,
#     'wind_kph': 9.4,
#     'wind_degree': 10,
#     'wind_dir': 'N',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 1,
#     'feelslike_c': 2.4,
#     'feelslike_f': 36.3,
#     'windchill_c': 2.4,
#     'windchill_f': 36.3,
#     'heatindex_c': 4.7,
#     'heatindex_f': 40.5,
#     'dewpoint_c': 1.7,
#     'dewpoint_f': 35.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 1.0},
#    {'time_epoch': 1624186800,
#     'time': '2021-06-20 08:00',
#     'temp_c': 4.6,
#     'temp_f': 40.3,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 10,
#     'wind_dir': 'N',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 1,
#     'feelslike_c': 2.2,
#     'feelslike_f': 36.0,
#     'windchill_c': 2.2,
#     'windchill_f': 36.0,
#     'heatindex_c': 4.6,
#     'heatindex_f': 40.3,
#     'dewpoint_c': 1.7,
#     'dewpoint_f': 35.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 1.0},
#    {'time_epoch': 1624190400,
#     'time': '2021-06-20 09:00',
#     'temp_c': 4.6,
#     'temp_f': 40.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 10,
#     'wind_dir': 'N',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.7,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 2,
#     'feelslike_c': 2.1,
#     'feelslike_f': 35.8,
#     'windchill_c': 2.1,
#     'windchill_f': 35.8,
#     'heatindex_c': 4.6,
#     'heatindex_f': 40.3,
#     'dewpoint_c': 1.6,
#     'dewpoint_f': 34.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.5,
#     'gust_kph': 20.2,
#     'uv': 2.0},
#    {'time_epoch': 1624194000,
#     'time': '2021-06-20 10:00',
#     'temp_c': 6.8,
#     'temp_f': 44.2,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.7,
#     'wind_kph': 14.0,
#     'wind_degree': 16,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 74,
#     'cloud': 8,
#     'feelslike_c': 4.4,
#     'feelslike_f': 39.9,
#     'windchill_c': 4.4,
#     'windchill_f': 39.9,
#     'heatindex_c': 6.8,
#     'heatindex_f': 44.2,
#     'dewpoint_c': 2.4,
#     'dewpoint_f': 36.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.4,
#     'gust_kph': 21.6,
#     'uv': 3.0},
#    {'time_epoch': 1624197600,
#     'time': '2021-06-20 11:00',
#     'temp_c': 9.1,
#     'temp_f': 48.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 10.7,
#     'wind_kph': 17.3,
#     'wind_degree': 22,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 67,
#     'cloud': 14,
#     'feelslike_c': 6.6,
#     'feelslike_f': 43.9,
#     'windchill_c': 6.6,
#     'windchill_f': 43.9,
#     'heatindex_c': 9.1,
#     'heatindex_f': 48.4,
#     'dewpoint_c': 3.2,
#     'dewpoint_f': 37.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.1,
#     'gust_kph': 22.7,
#     'uv': 3.0},
#    {'time_epoch': 1624201200,
#     'time': '2021-06-20 12:00',
#     'temp_c': 11.3,
#     'temp_f': 52.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 13.0,
#     'wind_kph': 20.9,
#     'wind_degree': 28,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 61,
#     'cloud': 20,
#     'feelslike_c': 8.9,
#     'feelslike_f': 48.0,
#     'windchill_c': 8.9,
#     'windchill_f': 48.0,
#     'heatindex_c': 11.3,
#     'heatindex_f': 52.3,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.0,
#     'gust_kph': 24.1,
#     'uv': 4.0},
#    {'time_epoch': 1624204800,
#     'time': '2021-06-20 13:00',
#     'temp_c': 12.2,
#     'temp_f': 54.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 13.6,
#     'wind_kph': 22.0,
#     'wind_degree': 31,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 58,
#     'cloud': 24,
#     'feelslike_c': 9.9,
#     'feelslike_f': 49.8,
#     'windchill_c': 9.9,
#     'windchill_f': 49.8,
#     'heatindex_c': 12.2,
#     'heatindex_f': 54.0,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.7,
#     'gust_kph': 25.2,
#     'uv': 4.0},
#    {'time_epoch': 1624208400,
#     'time': '2021-06-20 14:00',
#     'temp_c': 13.0,
#     'temp_f': 55.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 14.3,
#     'wind_kph': 23.0,
#     'wind_degree': 34,
#     'wind_dir': 'NE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 55,
#     'cloud': 29,
#     'feelslike_c': 11.0,
#     'feelslike_f': 51.8,
#     'windchill_c': 11.0,
#     'windchill_f': 51.8,
#     'heatindex_c': 13.0,
#     'heatindex_f': 55.4,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.6,
#     'gust_kph': 26.6,
#     'uv': 4.0},
#    {'time_epoch': 1624212000,
#     'time': '2021-06-20 15:00',
#     'temp_c': 13.9,
#     'temp_f': 57.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 15.0,
#     'wind_kph': 24.1,
#     'wind_degree': 37,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 52,
#     'cloud': 33,
#     'feelslike_c': 12.0,
#     'feelslike_f': 53.6,
#     'windchill_c': 12.0,
#     'windchill_f': 53.6,
#     'heatindex_c': 13.9,
#     'heatindex_f': 57.0,
#     'dewpoint_c': 4.2,
#     'dewpoint_f': 39.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.2,
#     'gust_kph': 27.7,
#     'uv': 4.0},
#    {'time_epoch': 1624215600,
#     'time': '2021-06-20 16:00',
#     'temp_c': 12.8,
#     'temp_f': 55.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 14.1,
#     'wind_kph': 22.7,
#     'wind_degree': 39,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 56,
#     'cloud': 32,
#     'feelslike_c': 10.7,
#     'feelslike_f': 51.3,
#     'windchill_c': 10.7,
#     'windchill_f': 51.3,
#     'heatindex_c': 12.8,
#     'heatindex_f': 55.0,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.7,
#     'gust_kph': 28.4,
#     'uv': 4.0},
#    {'time_epoch': 1624219200,
#     'time': '2021-06-20 17:00',
#     'temp_c': 11.7,
#     'temp_f': 53.1,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 13.0,
#     'wind_kph': 20.9,
#     'wind_degree': 41,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 60,
#     'cloud': 32,
#     'feelslike_c': 9.5,
#     'feelslike_f': 49.1,
#     'windchill_c': 9.5,
#     'windchill_f': 49.1,
#     'heatindex_c': 11.7,
#     'heatindex_f': 53.1,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.3,
#     'gust_kph': 29.5,
#     'uv': 4.0},
#    {'time_epoch': 1624222800,
#     'time': '2021-06-20 18:00',
#     'temp_c': 10.6,
#     'temp_f': 51.1,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 12.1,
#     'wind_kph': 19.4,
#     'wind_degree': 42,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 64,
#     'cloud': 31,
#     'feelslike_c': 8.2,
#     'feelslike_f': 46.8,
#     'windchill_c': 8.2,
#     'windchill_f': 46.8,
#     'heatindex_c': 10.6,
#     'heatindex_f': 51.1,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.8,
#     'gust_kph': 30.2,
#     'uv': 4.0},
#    {'time_epoch': 1624226400,
#     'time': '2021-06-20 19:00',
#     'temp_c': 9.6,
#     'temp_f': 49.3,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 10.5,
#     'wind_kph': 16.9,
#     'wind_degree': 29,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 30,
#     'feelslike_c': 7.3,
#     'feelslike_f': 45.1,
#     'windchill_c': 7.3,
#     'windchill_f': 45.1,
#     'heatindex_c': 9.6,
#     'heatindex_f': 49.3,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.4,
#     'gust_kph': 28.1,
#     'uv': 1.0},
#    {'time_epoch': 1624230000,
#     'time': '2021-06-20 20:00',
#     'temp_c': 8.6,
#     'temp_f': 47.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 8.9,
#     'wind_kph': 14.4,
#     'wind_degree': 16,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 29,
#     'feelslike_c': 6.3,
#     'feelslike_f': 43.3,
#     'windchill_c': 6.3,
#     'windchill_f': 43.3,
#     'heatindex_c': 8.6,
#     'heatindex_f': 47.5,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.1,
#     'gust_kph': 25.9,
#     'uv': 1.0},
#    {'time_epoch': 1624233600,
#     'time': '2021-06-20 21:00',
#     'temp_c': 7.6,
#     'temp_f': 45.7,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.4,
#     'wind_kph': 11.9,
#     'wind_degree': 3,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 78,
#     'cloud': 29,
#     'feelslike_c': 5.4,
#     'feelslike_f': 41.7,
#     'windchill_c': 5.4,
#     'windchill_f': 41.7,
#     'heatindex_c': 7.6,
#     'heatindex_f': 45.7,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.8,
#     'gust_kph': 23.8,
#     'uv': 1.0},
#    {'time_epoch': 1624237200,
#     'time': '2021-06-20 22:00',
#     'temp_c': 7.4,
#     'temp_f': 45.3,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 2,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 78,
#     'cloud': 24,
#     'feelslike_c': 5.2,
#     'feelslike_f': 41.4,
#     'windchill_c': 5.2,
#     'windchill_f': 41.4,
#     'heatindex_c': 7.4,
#     'heatindex_f': 45.3,
#     'dewpoint_c': 3.9,
#     'dewpoint_f': 39.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.8,
#     'gust_kph': 23.8,
#     'uv': 1.0},
#    {'time_epoch': 1624240800,
#     'time': '2021-06-20 23:00',
#     'temp_c': 7.2,
#     'temp_f': 45.0,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 1,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 20,
#     'feelslike_c': 5.0,
#     'feelslike_f': 41.0,
#     'windchill_c': 5.0,
#     'windchill_f': 41.0,
#     'heatindex_c': 7.2,
#     'heatindex_f': 45.0,
#     'dewpoint_c': 3.9,
#     'dewpoint_f': 39.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.5,
#     'gust_kph': 23.4,
#     'uv': 1.0}]},
#  {'date': '2021-06-21',
#   'date_epoch': 1624233600,
#   'day': {'maxtemp_c': 17.1,
#    'maxtemp_f': 62.8,
#    'mintemp_c': 6.6,
#    'mintemp_f': 43.9,
#    'avgtemp_c': 10.1,
#    'avgtemp_f': 50.1,
#    'maxwind_mph': 8.3,
#    'maxwind_kph': 13.3,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 73.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'uv': 3.0},
#   'astro': {'sunrise': '08:15 AM',
#    'sunset': '06:22 PM',
#    'moonrise': '03:46 PM',
#    'moonset': '04:30 AM',
#    'moon_phase': 'Full Moon',
#    'moon_illumination': '83'},
#   'hour': [{'time_epoch': 1624244400,
#     'time': '2021-06-21 00:00',
#     'temp_c': 7.0,
#     'temp_f': 44.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 1,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 16,
#     'feelslike_c': 4.8,
#     'feelslike_f': 40.6,
#     'windchill_c': 4.8,
#     'windchill_f': 40.6,
#     'heatindex_c': 7.0,
#     'heatindex_f': 44.6,
#     'dewpoint_c': 3.8,
#     'dewpoint_f': 38.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.5,
#     'gust_kph': 23.4,
#     'uv': 1.0},
#    {'time_epoch': 1624248000,
#     'time': '2021-06-21 01:00',
#     'temp_c': 6.9,
#     'temp_f': 44.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 120,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 18,
#     'feelslike_c': 4.8,
#     'feelslike_f': 40.6,
#     'windchill_c': 4.8,
#     'windchill_f': 40.6,
#     'heatindex_c': 6.9,
#     'heatindex_f': 44.4,
#     'dewpoint_c': 3.8,
#     'dewpoint_f': 38.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.6,
#     'gust_kph': 22.0,
#     'uv': 1.0},
#    {'time_epoch': 1624251600,
#     'time': '2021-06-21 02:00',
#     'temp_c': 6.8,
#     'temp_f': 44.2,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 238,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 21,
#     'feelslike_c': 4.9,
#     'feelslike_f': 40.8,
#     'windchill_c': 4.9,
#     'windchill_f': 40.8,
#     'heatindex_c': 6.8,
#     'heatindex_f': 44.2,
#     'dewpoint_c': 3.9,
#     'dewpoint_f': 39.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.5,
#     'gust_kph': 20.2,
#     'uv': 1.0},
#    {'time_epoch': 1624255200,
#     'time': '2021-06-21 03:00',
#     'temp_c': 6.7,
#     'temp_f': 44.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 357,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 23,
#     'feelslike_c': 4.9,
#     'feelslike_f': 40.8,
#     'windchill_c': 4.9,
#     'windchill_f': 40.8,
#     'heatindex_c': 6.7,
#     'heatindex_f': 44.1,
#     'dewpoint_c': 3.9,
#     'dewpoint_f': 39.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 1.0},
#    {'time_epoch': 1624258800,
#     'time': '2021-06-21 04:00',
#     'temp_c': 6.7,
#     'temp_f': 44.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 352,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 83,
#     'cloud': 18,
#     'feelslike_c': 5.5,
#     'feelslike_f': 41.9,
#     'windchill_c': 5.5,
#     'windchill_f': 41.9,
#     'heatindex_c': 6.7,
#     'heatindex_f': 44.1,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.7,
#     'gust_kph': 14.0,
#     'uv': 1.0},
#    {'time_epoch': 1624262400,
# ...
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 84,
#     'cloud': 14,
#     'feelslike_c': 6.0,
#     'feelslike_f': 42.8,
#     'windchill_c': 6.0,
#     'windchill_f': 42.8,
#     'heatindex_c': 6.6,
#     'heatindex_f': 43.9,
#     'dewpoint_c': 4.2,
#     'dewpoint_f': 39.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.0,
#     'gust_kph': 9.7,
#     'uv': 1.0},
#    {'time_epoch': 1624266000,
#     'time': '2021-06-21 06:00',
#     'temp_c': 6.6,
#     'temp_f': 43.9,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 1.6,
#     'wind_kph': 2.5,
#     'wind_degree': 341,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 9,
#     'feelslike_c': 6.6,
#     'feelslike_f': 43.9,
#     'windchill_c': 6.6,
#     'windchill_f': 43.9,
#     'heatindex_c': 6.6,
#     'heatindex_f': 43.9,
#     'dewpoint_c': 4.3,
#     'dewpoint_f': 39.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.1,
#     'gust_kph': 5.0,
#     'uv': 1.0},
#    {'time_epoch': 1624269600,
#     'time': '2021-06-21 07:00',
#     'temp_c': 6.7,
#     'temp_f': 44.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 342,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 8,
#     'feelslike_c': 6.7,
#     'feelslike_f': 44.1,
#     'windchill_c': 6.7,
#     'windchill_f': 44.1,
#     'heatindex_c': 6.7,
#     'heatindex_f': 44.1,
#     'dewpoint_c': 4.4,
#     'dewpoint_f': 39.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.5,
#     'gust_kph': 4.0,
#     'uv': 1.0},
#    {'time_epoch': 1624273200,
#     'time': '2021-06-21 08:00',
#     'temp_c': 6.8,
#     'temp_f': 44.2,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 0.9,
#     'wind_kph': 1.4,
#     'wind_degree': 343,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 6,
#     'feelslike_c': 6.8,
#     'feelslike_f': 44.2,
#     'windchill_c': 6.8,
#     'windchill_f': 44.2,
#     'heatindex_c': 6.8,
#     'heatindex_f': 44.2,
#     'dewpoint_c': 4.4,
#     'dewpoint_f': 39.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 1.8,
#     'gust_kph': 2.9,
#     'uv': 1.0},
#    {'time_epoch': 1624276800,
#     'time': '2021-06-21 09:00',
#     'temp_c': 6.9,
#     'temp_f': 44.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 0.7,
#     'wind_kph': 1.1,
#     'wind_degree': 345,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 84,
#     'cloud': 5,
#     'feelslike_c': 6.9,
#     'feelslike_f': 44.4,
#     'windchill_c': 6.9,
#     'windchill_f': 44.4,
#     'heatindex_c': 6.9,
#     'heatindex_f': 44.4,
#     'dewpoint_c': 4.5,
#     'dewpoint_f': 40.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 1.1,
#     'gust_kph': 1.8,
#     'uv': 3.0},
#    {'time_epoch': 1624280400,
#     'time': '2021-06-21 10:00',
#     'temp_c': 9.0,
#     'temp_f': 48.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.6,
#     'wind_kph': 2.5,
#     'wind_degree': 249,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 4,
#     'feelslike_c': 9.0,
#     'feelslike_f': 48.2,
#     'windchill_c': 9.0,
#     'windchill_f': 48.2,
#     'heatindex_c': 9.0,
#     'heatindex_f': 48.2,
#     'dewpoint_c': 4.9,
#     'dewpoint_f': 40.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.0,
#     'gust_kph': 3.2,
#     'uv': 3.0},
#    {'time_epoch': 1624284000,
#     'time': '2021-06-21 11:00',
#     'temp_c': 11.1,
#     'temp_f': 52.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 2.5,
#     'wind_kph': 4.0,
#     'wind_degree': 153,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 2,
#     'feelslike_c': 11.2,
#     'feelslike_f': 52.2,
#     'windchill_c': 11.2,
#     'windchill_f': 52.2,
#     'heatindex_c': 11.1,
#     'heatindex_f': 52.0,
#     'dewpoint_c': 5.3,
#     'dewpoint_f': 41.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.9,
#     'gust_kph': 4.7,
#     'uv': 4.0},
#    {'time_epoch': 1624287600,
#     'time': '2021-06-21 12:00',
#     'temp_c': 13.2,
#     'temp_f': 55.8,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 57,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 60,
#     'cloud': 0,
#     'feelslike_c': 13.3,
#     'feelslike_f': 55.9,
#     'windchill_c': 13.3,
#     'windchill_f': 55.9,
#     'heatindex_c': 13.2,
#     'heatindex_f': 55.8,
#     'dewpoint_c': 5.7,
#     'dewpoint_f': 42.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.8,
#     'gust_kph': 6.1,
#     'uv': 4.0},
#    {'time_epoch': 1624291200,
#     'time': '2021-06-21 13:00',
#     'temp_c': 14.5,
#     'temp_f': 58.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 63,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 56,
#     'cloud': 0,
#     'feelslike_c': 14.6,
#     'feelslike_f': 58.3,
#     'windchill_c': 14.6,
#     'windchill_f': 58.3,
#     'heatindex_c': 14.5,
#     'heatindex_f': 58.1,
#     'dewpoint_c': 5.7,
#     'dewpoint_f': 42.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.5,
#     'gust_kph': 7.2,
#     'uv': 4.0},
#    {'time_epoch': 1624294800,
#     'time': '2021-06-21 14:00',
#     'temp_c': 15.8,
#     'temp_f': 60.4,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 69,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 52,
#     'cloud': 0,
#     'feelslike_c': 15.8,
#     'feelslike_f': 60.4,
#     'windchill_c': 15.8,
#     'windchill_f': 60.4,
#     'heatindex_c': 15.8,
#     'heatindex_f': 60.4,
#     'dewpoint_c': 5.8,
#     'dewpoint_f': 42.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.1,
#     'gust_kph': 8.3,
#     'uv': 5.0},
#    {'time_epoch': 1624298400,
#     'time': '2021-06-21 15:00',
#     'temp_c': 17.1,
#     'temp_f': 62.8,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 75,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 47,
#     'cloud': 0,
#     'feelslike_c': 17.1,
#     'feelslike_f': 62.8,
#     'windchill_c': 17.1,
#     'windchill_f': 62.8,
#     'heatindex_c': 17.1,
#     'heatindex_f': 62.8,
#     'dewpoint_c': 5.8,
#     'dewpoint_f': 42.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.8,
#     'gust_kph': 9.4,
#     'uv': 5.0},
#    {'time_epoch': 1624302000,
#     'time': '2021-06-21 16:00',
#     'temp_c': 15.7,
#     'temp_f': 60.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 68,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 53,
#     'cloud': 1,
#     'feelslike_c': 15.3,
#     'feelslike_f': 59.5,
#     'windchill_c': 15.3,
#     'windchill_f': 59.5,
#     'heatindex_c': 15.7,
#     'heatindex_f': 60.3,
#     'dewpoint_c': 5.9,
#     'dewpoint_f': 42.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.3,
#     'gust_kph': 13.3,
#     'uv': 5.0},
#    {'time_epoch': 1624305600,
#     'time': '2021-06-21 17:00',
#     'temp_c': 14.3,
#     'temp_f': 57.7,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 62,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 58,
#     'cloud': 2,
#     'feelslike_c': 13.5,
#     'feelslike_f': 56.3,
#     'windchill_c': 13.5,
#     'windchill_f': 56.3,
#     'heatindex_c': 14.3,
#     'heatindex_f': 57.7,
#     'dewpoint_c': 6.1,
#     'dewpoint_f': 43.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.7,
#     'gust_kph': 17.3,
#     'uv': 4.0},
#    {'time_epoch': 1624309200,
#     'time': '2021-06-21 18:00',
#     'temp_c': 12.9,
#     'temp_f': 55.2,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.3,
#     'wind_kph': 13.3,
#     'wind_degree': 55,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 63,
#     'cloud': 4,
#     'feelslike_c': 11.7,
#     'feelslike_f': 53.1,
#     'windchill_c': 11.7,
#     'windchill_f': 53.1,
#     'heatindex_c': 12.9,
#     'heatindex_f': 55.2,
#     'dewpoint_c': 6.2,
#     'dewpoint_f': 43.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.2,
#     'gust_kph': 21.2,
#     'uv': 4.0},
#    {'time_epoch': 1624312800,
#     'time': '2021-06-21 19:00',
#     'temp_c': 12.0,
#     'temp_f': 53.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.6,
#     'wind_kph': 12.2,
#     'wind_degree': 38,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 69,
#     'cloud': 5,
#     'feelslike_c': 10.7,
#     'feelslike_f': 51.3,
#     'windchill_c': 10.7,
#     'windchill_f': 51.3,
#     'heatindex_c': 12.0,
#     'heatindex_f': 53.6,
#     'dewpoint_c': 6.5,
#     'dewpoint_f': 43.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.8,
#     'gust_kph': 20.5,
#     'uv': 1.0},
#    {'time_epoch': 1624316400,
#     'time': '2021-06-21 20:00',
#     'temp_c': 11.1,
#     'temp_f': 52.0,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 20,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 5,
#     'feelslike_c': 9.8,
#     'feelslike_f': 49.6,
#     'windchill_c': 9.8,
#     'windchill_f': 49.6,
#     'heatindex_c': 11.1,
#     'heatindex_f': 52.0,
#     'dewpoint_c': 6.7,
#     'dewpoint_f': 44.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 1.0},
#    {'time_epoch': 1624320000,
#     'time': '2021-06-21 21:00',
#     'temp_c': 10.2,
#     'temp_f': 50.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 2,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 6,
#     'feelslike_c': 8.8,
#     'feelslike_f': 47.8,
#     'windchill_c': 8.8,
#     'windchill_f': 47.8,
#     'heatindex_c': 10.2,
#     'heatindex_f': 50.4,
#     'dewpoint_c': 7.0,
#     'dewpoint_f': 44.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 1.0},
#    {'time_epoch': 1624323600,
#     'time': '2021-06-21 22:00',
#     'temp_c': 10.2,
#     'temp_f': 50.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 121,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 4,
#     'feelslike_c': 8.9,
#     'feelslike_f': 48.0,
#     'windchill_c': 8.9,
#     'windchill_f': 48.0,
#     'heatindex_c': 10.2,
#     'heatindex_f': 50.4,
#     'dewpoint_c': 7.2,
#     'dewpoint_f': 45.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.0,
#     'gust_kph': 17.6,
#     'uv': 1.0},
#    {'time_epoch': 1624327200,
#     'time': '2021-06-21 23:00',
#     'temp_c': 10.2,
#     'temp_f': 50.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 240,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 2,
#     'feelslike_c': 8.9,
#     'feelslike_f': 48.0,
#     'windchill_c': 8.9,
#     'windchill_f': 48.0,
#     'heatindex_c': 10.2,
#     'heatindex_f': 50.4,
#     'dewpoint_c': 7.3,
#     'dewpoint_f': 45.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 1.0}]}]

# %%
for daily_forecast in data['forecast']['forecastday']:
    print(f"On {daily_forecast['date']}, the max temperature will be {daily_forecast['day']['maxtemp_f']} degrees Fahrenheit")
    
    if daily_forecast['day']['maxtemp_f'] > 90:
        print("It's a hot day")
    elif daily_forecast['day']['maxtemp_f'] < 70:
        print("It's a cold day.")
    else:
        print("It's warm!")
# Out:
# On 2021-06-19, the max temperature will be 51.3 degrees Fahrenheit
# It's a cold day.
# On 2021-06-20, the max temperature will be 57.0 degrees Fahrenheit
# It's a cold day.
# On 2021-06-21, the max temperature will be 62.8 degrees Fahrenheit
# It's a cold day.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
# - *Tip: You'll only need one day of forecast*

# %%
response = requests.get(f"http://api.weatherapi.com/v1/forecast.json?key={api_key_weather}&q=Miami&days=1&aqi=no&alerts=no")

# %%
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'Miami',
#   'region': 'Florida',
#   'country': 'United States of America',
#   'lat': 25.77,
#   'lon': -80.19,
#   'tz_id': 'America/Kentucky/Monticello',
#   'localtime_epoch': 1624215945,
#   'localtime': '2021-06-20 15:05'},
#  'current': {'last_updated_epoch': 1624212000,
#   'last_updated': '2021-06-20 14:00',
#   'temp_c': 32.8,
#   'temp_f': 91.0,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 12.5,
#   'wind_kph': 20.2,
#   'wind_degree': 150,
#   'wind_dir': 'SSE',
#   'pressure_mb': 1018.0,
#   'pressure_in': 30.5,
#   'precip_mm': 0.6,
#   'precip_in': 0.02,
#   'humidity': 64,
#   'cloud': 75,
#   'feelslike_c': 43.7,
#   'feelslike_f': 110.7,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 6.0,
#   'gust_mph': 16.1,
#   'gust_kph': 25.9},
#  'forecast': {'forecastday': [{'date': '2021-06-20',
#     'date_epoch': 1624147200,
#     'day': {'maxtemp_c': 29.6,
#      'maxtemp_f': 85.3,
#      'mintemp_c': 27.9,
#      'mintemp_f': 82.2,
#      'avgtemp_c': 28.8,
#      'avgtemp_f': 83.9,
#      'maxwind_mph': 13.6,
#      'maxwind_kph': 22.0,
#      'totalprecip_mm': 5.9,
#      'totalprecip_in': 0.23,
#      'avgvis_km': 9.5,
#      'avgvis_miles': 5.0,
#      'avghumidity': 77.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': '87',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Moderate rain',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#       'code': 1189},
#      'uv': 9.0},
#     'astro': {'sunrise': '06:29 AM',
#      'sunset': '08:15 PM',
#      'moonrise': '03:59 PM',
#      'moonset': '02:57 AM',
#      'moon_phase': 'Full Moon',
#      'moon_illumination': '76'},
#     'hour': [{'time_epoch': 1624161600,
#       'time': '2021-06-20 00:00',
#       'temp_c': 28.3,
#       'temp_f': 82.9,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 109,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 71,
#       'feelslike_c': 32.9,
#       'feelslike_f': 91.2,
#       'windchill_c': 28.3,
#       'windchill_f': 82.9,
#       'heatindex_c': 32.9,
#       'heatindex_f': 91.2,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '29',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.6,
#       'gust_kph': 26.6,
#       'uv': 1.0},
#      {'time_epoch': 1624165200,
#       'time': '2021-06-20 01:00',
#       'temp_c': 28.3,
#       'temp_f': 82.9,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 117,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 77,
#       'feelslike_c': 32.9,
#       'feelslike_f': 91.2,
#       'windchill_c': 28.3,
#       'windchill_f': 82.9,
#       'heatindex_c': 32.9,
#       'heatindex_f': 91.2,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '58',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.6,
#       'gust_kph': 26.6,
#       'uv': 1.0},
#      {'time_epoch': 1624168800,
#       'time': '2021-06-20 02:00',
#       'temp_c': 28.3,
#       'temp_f': 82.9,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 126,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 84,
#       'feelslike_c': 32.8,
#       'feelslike_f': 91.0,
#       'windchill_c': 28.3,
#       'windchill_f': 82.9,
#       'heatindex_c': 32.8,
#       'heatindex_f': 91.0,
#       'dewpoint_c': 24.3,
#       'dewpoint_f': 75.7,
#       'will_it_rain': 1,
#       'chance_of_rain': '87',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.6,
#       'gust_kph': 26.6,
#       'uv': 1.0},
#      {'time_epoch': 1624172400,
#       'time': '2021-06-20 03:00',
#       'temp_c': 28.2,
#       'temp_f': 82.8,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 139,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.6,
#       'precip_in': 0.02,
#       'humidity': 80,
#       'cloud': 73,
#       'feelslike_c': 32.7,
#       'feelslike_f': 90.9,
#       'windchill_c': 28.2,
#       'windchill_f': 82.8,
#       'heatindex_c': 32.7,
#       'heatindex_f': 90.9,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 1,
#       'chance_of_rain': '82',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.8,
#       'gust_kph': 27.0,
#       'uv': 1.0},
#      {'time_epoch': 1624176000,
#       'time': '2021-06-20 04:00',
#       'temp_c': 28.0,
#       'temp_f': 82.4,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 151,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 1.0,
#       'precip_in': 0.04,
#       'humidity': 81,
#       'cloud': 63,
#       'feelslike_c': 32.6,
#       'feelslike_f': 90.7,
#       'windchill_c': 28.0,
#       'windchill_f': 82.4,
#       'heatindex_c': 32.6,
#       'heatindex_f': 90.7,
#       'dewpoint_c': 24.5,
#       'dewpoint_f': 76.1,
#       'will_it_rain': 1,
#       'chance_of_rain': '76',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.8,
#       'gust_kph': 27.0,
#       'uv': 1.0},
#      {'time_epoch': 1624179600,
#       'time': '2021-06-20 05:00',
#       'temp_c': 27.9,
#       'temp_f': 82.2,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 164,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 1.5,
#       'precip_in': 0.06,
#       'humidity': 82,
#       'cloud': 52,
#       'feelslike_c': 32.5,
#       'feelslike_f': 90.5,
#       'windchill_c': 27.9,
#       'windchill_f': 82.2,
#       'heatindex_c': 32.5,
#       'heatindex_f': 90.5,
#       'dewpoint_c': 24.6,
#       'dewpoint_f': 76.3,
#       'will_it_rain': 1,
#       'chance_of_rain': '71',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.4,
#       'uv': 1.0},
#      {'time_epoch': 1624183200,
#       'time': '2021-06-20 06:00',
#       'temp_c': 28.0,
#       'temp_f': 82.4,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 166,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 1.2,
#       'precip_in': 0.05,
#       'humidity': 82,
#       'cloud': 57,
#       'feelslike_c': 32.6,
#       'feelslike_f': 90.7,
#       'windchill_c': 28.0,
#       'windchill_f': 82.4,
#       'heatindex_c': 32.6,
#       'heatindex_f': 90.7,
#       'dewpoint_c': 24.6,
#       'dewpoint_f': 76.3,
#       'will_it_rain': 1,
#       'chance_of_rain': '72',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.6,
#       'gust_kph': 26.6,
#       'uv': 1.0},
#      {'time_epoch': 1624186800,
#       'time': '2021-06-20 07:00',
#       'temp_c': 28.2,
#       'temp_f': 82.8,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 169,
#       'wind_dir': 'S',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.8,
#       'precip_in': 0.03,
#       'humidity': 81,
#       'cloud': 61,
#       'feelslike_c': 32.8,
#       'feelslike_f': 91.0,
#       'windchill_c': 28.2,
#       'windchill_f': 82.8,
#       'heatindex_c': 32.8,
#       'heatindex_f': 91.0,
#       'dewpoint_c': 24.5,
#       'dewpoint_f': 76.1,
#       'will_it_rain': 1,
#       'chance_of_rain': '73',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.9,
#       'gust_kph': 25.6,
#       'uv': 6.0},
#      {'time_epoch': 1624190400,
#       'time': '2021-06-20 08:00',
#       'temp_c': 28.3,
#       'temp_f': 82.9,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 172,
#       'wind_dir': 'S',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.5,
#       'precip_in': 0.02,
#       'humidity': 80,
#       'cloud': 66,
#       'feelslike_c': 32.9,
#       'feelslike_f': 91.2,
#       'windchill_c': 28.3,
#       'windchill_f': 82.9,
#       'heatindex_c': 32.9,
#       'heatindex_f': 91.2,
#       'dewpoint_c': 24.5,
#       'dewpoint_f': 76.1,
#       'will_it_rain': 1,
#       'chance_of_rain': '74',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 6.0},
#      {'time_epoch': 1624194000,
#       'time': '2021-06-20 09:00',
#       'temp_c': 28.7,
#       'temp_f': 83.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 171,
#       'wind_dir': 'S',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.5,
#       'precip_in': 0.02,
#       'humidity': 78,
#       'cloud': 67,
#       'feelslike_c': 33.4,
#       'feelslike_f': 92.1,
#       'windchill_c': 28.7,
#       'windchill_f': 83.7,
#       'heatindex_c': 33.4,
#       'heatindex_f': 92.1,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 1,
#       'chance_of_rain': '73',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.7,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 6.0},
#      {'time_epoch': 1624197600,
#       'time': '2021-06-20 10:00',
#       'temp_c': 29.0,
#       'temp_f': 84.2,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 171,
#       'wind_dir': 'S',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 76,
#       'cloud': 69,
#       'feelslike_c': 33.9,
#       'feelslike_f': 93.0,
#       'windchill_c': 29.0,
#       'windchill_f': 84.2,
#       'heatindex_c': 33.9,
#       'heatindex_f': 93.0,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 1,
#       'chance_of_rain': '72',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.3,
#       'vis_miles': 5.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 6.0},
#      {'time_epoch': 1624201200,
#       'time': '2021-06-20 11:00',
#       'temp_c': 29.4,
#       'temp_f': 84.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 170,
#       'wind_dir': 'S',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 74,
#       'cloud': 70,
#       'feelslike_c': 34.4,
#       'feelslike_f': 93.9,
#       'windchill_c': 29.4,
#       'windchill_f': 84.9,
#       'heatindex_c': 34.4,
#       'heatindex_f': 93.9,
#       'dewpoint_c': 24.3,
#       'dewpoint_f': 75.7,
#       'will_it_rain': 1,
#       'chance_of_rain': '71',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 6.0},
#      {'time_epoch': 1624204800,
#       'time': '2021-06-20 12:00',
#       'temp_c': 29.5,
#       'temp_f': 85.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 165,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.6,
#       'precip_in': 0.02,
#       'humidity': 74,
#       'cloud': 71,
#       'feelslike_c': 34.5,
#       'feelslike_f': 94.1,
#       'windchill_c': 29.5,
#       'windchill_f': 85.1,
#       'heatindex_c': 34.5,
#       'heatindex_f': 94.1,
#       'dewpoint_c': 24.3,
#       'dewpoint_f': 75.7,
#       'will_it_rain': 1,
#       'chance_of_rain': '73',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 16.1,
#       'gust_kph': 25.9,
#       'uv': 6.0},
#      {'time_epoch': 1624208400,
#       'time': '2021-06-20 13:00',
#       'temp_c': 29.5,
#       'temp_f': 85.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 160,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.8,
#       'precip_in': 0.03,
#       'humidity': 74,
#       'cloud': 72,
#       'feelslike_c': 34.7,
#       'feelslike_f': 94.5,
#       'windchill_c': 29.5,
#       'windchill_f': 85.1,
#       'heatindex_c': 34.7,
#       'heatindex_f': 94.5,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 1,
#       'chance_of_rain': '76',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.4,
#       'uv': 6.0},
#      {'time_epoch': 1624212000,
#       'time': '2021-06-20 14:00',
#       'temp_c': 29.6,
#       'temp_f': 85.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.6,
#       'wind_kph': 22.0,
#       'wind_degree': 155,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 1.0,
#       'precip_in': 0.04,
#       'humidity': 74,
#       'cloud': 73,
#       'feelslike_c': 34.8,
#       'feelslike_f': 94.6,
#       'windchill_c': 29.6,
#       'windchill_f': 85.3,
#       'heatindex_c': 34.8,
#       'heatindex_f': 94.6,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 1,
#       'chance_of_rain': '78',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 17.9,
#       'gust_kph': 28.8,
#       'uv': 6.0},
#      {'time_epoch': 1624215600,
#       'time': '2021-06-20 15:00',
#       'temp_c': 29.5,
#       'temp_f': 85.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.2,
#       'wind_kph': 21.2,
#       'wind_degree': 158,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 1.3,
#       'precip_in': 0.05,
#       'humidity': 73,
#       'cloud': 78,
#       'feelslike_c': 34.6,
#       'feelslike_f': 94.3,
#       'windchill_c': 29.5,
#       'windchill_f': 85.1,
#       'heatindex_c': 34.6,
#       'heatindex_f': 94.3,
#       'dewpoint_c': 24.3,
#       'dewpoint_f': 75.7,
#       'will_it_rain': 1,
#       'chance_of_rain': '75',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 18.1,
#       'gust_kph': 29.2,
#       'uv': 6.0},
#      {'time_epoch': 1624219200,
#       'time': '2021-06-20 16:00',
#       'temp_c': 29.5,
#       'temp_f': 85.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.8,
#       'wind_kph': 20.5,
#       'wind_degree': 161,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 1.7,
#       'precip_in': 0.07,
#       'humidity': 73,
#       'cloud': 82,
#       'feelslike_c': 34.4,
#       'feelslike_f': 93.9,
#       'windchill_c': 29.5,
#       'windchill_f': 85.1,
#       'heatindex_c': 34.4,
#       'heatindex_f': 93.9,
#       'dewpoint_c': 24.1,
#       'dewpoint_f': 75.4,
#       'will_it_rain': 1,
#       'chance_of_rain': '72',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 18.1,
#       'gust_kph': 29.2,
#       'uv': 6.0},
#      {'time_epoch': 1624222800,
#       'time': '2021-06-20 17:00',
#       'temp_c': 29.4,
#       'temp_f': 84.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 163,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 2.0,
#       'precip_in': 0.08,
#       'humidity': 73,
#       'cloud': 87,
#       'feelslike_c': 34.2,
#       'feelslike_f': 93.6,
#       'windchill_c': 29.4,
#       'windchill_f': 84.9,
#       'heatindex_c': 34.2,
#       'heatindex_f': 93.6,
#       'dewpoint_c': 24.0,
#       'dewpoint_f': 75.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '69',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 18.3,
#       'gust_kph': 29.5,
#       'uv': 6.0},
#      {'time_epoch': 1624226400,
#       'time': '2021-06-20 18:00',
#       'temp_c': 29.3,
#       'temp_f': 84.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 166,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.5,
#       'precip_mm': 1.3,
#       'precip_in': 0.05,
#       'humidity': 74,
#       'cloud': 65,
#       'feelslike_c': 34.1,
#       'feelslike_f': 93.4,
#       'windchill_c': 29.3,
#       'windchill_f': 84.7,
#       'heatindex_c': 34.1,
#       'heatindex_f': 93.4,
#       'dewpoint_c': 24.1,
#       'dewpoint_f': 75.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '46',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.3,
#       'vis_miles': 5.0,
#       'gust_mph': 17.4,
#       'gust_kph': 28.1,
#       'uv': 7.0},
#      {'time_epoch': 1624230000,
#       'time': '2021-06-20 19:00',
#       'temp_c': 29.1,
#       'temp_f': 84.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 168,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.7,
#       'precip_in': 0.03,
#       'humidity': 75,
#       'cloud': 43,
#       'feelslike_c': 34.0,
#       'feelslike_f': 93.2,
#       'windchill_c': 29.1,
#       'windchill_f': 84.4,
#       'heatindex_c': 34.0,
#       'heatindex_f': 93.2,
#       'dewpoint_c': 24.2,
#       'dewpoint_f': 75.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '23',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.7,
#       'vis_miles': 6.0,
#       'gust_mph': 16.3,
#       'gust_kph': 26.3,
#       'uv': 6.0},
#      {'time_epoch': 1624233600,
#       'time': '2021-06-20 20:00',
#       'temp_c': 29.0,
#       'temp_f': 84.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 171,
#       'wind_dir': 'S',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 21,
#       'feelslike_c': 33.9,
#       'feelslike_f': 93.0,
#       'windchill_c': 29.0,
#       'windchill_f': 84.2,
#       'heatindex_c': 33.9,
#       'heatindex_f': 93.0,
#       'dewpoint_c': 24.3,
#       'dewpoint_f': 75.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 7.0},
#      {'time_epoch': 1624237200,
#       'time': '2021-06-20 21:00',
#       'temp_c': 28.9,
#       'temp_f': 84.0,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 11.0,
#       'wind_kph': 17.6,
#       'wind_degree': 172,
#       'wind_dir': 'S',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 40,
#       'feelslike_c': 33.7,
#       'feelslike_f': 92.7,
#       'windchill_c': 28.9,
#       'windchill_f': 84.0,
#       'heatindex_c': 33.7,
#       'heatindex_f': 92.7,
#       'dewpoint_c': 24.3,
#       'dewpoint_f': 75.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '26',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.7,
#       'vis_miles': 6.0,
#       'gust_mph': 15.0,
#       'gust_kph': 24.1,
#       'uv': 1.0},
#      {'time_epoch': 1624240800,
#       'time': '2021-06-20 22:00',
#       'temp_c': 28.7,
#       'temp_f': 83.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 174,
#       'wind_dir': 'S',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.5,
#       'precip_mm': 0.3,
#       'precip_in': 0.01,
#       'humidity': 77,
#       'cloud': 60,
#       'feelslike_c': 33.5,
#       'feelslike_f': 92.3,
#       'windchill_c': 28.7,
#       'windchill_f': 83.7,
#       'heatindex_c': 33.5,
#       'heatindex_f': 92.3,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '52',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.3,
#       'vis_miles': 5.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.4,
#       'uv': 1.0},
#      {'time_epoch': 1624244400,
#       'time': '2021-06-20 23:00',
#       'temp_c': 28.6,
#       'temp_f': 83.5,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 175,
#       'wind_dir': 'S',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.6,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 78,
#       'cloud': 80,
#       'feelslike_c': 33.3,
#       'feelslike_f': 91.9,
#       'windchill_c': 28.6,
#       'windchill_f': 83.5,
#       'heatindex_c': 33.3,
#       'heatindex_f': 91.9,
#       'dewpoint_c': 24.4,
#       'dewpoint_f': 75.9,
#       'will_it_rain': 1,
#       'chance_of_rain': '78',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 1.0}]}]}}

# %%
data['forecast']['forecastday']
# Out:
# [{'date': '2021-06-19',
#   'date_epoch': 1624060800,
#   'day': {'maxtemp_c': 29.2,
#    'maxtemp_f': 84.6,
#    'mintemp_c': 27.9,
#    'mintemp_f': 82.2,
#    'avgtemp_c': 28.5,
#    'avgtemp_f': 83.3,
#    'maxwind_mph': 15.9,
#    'maxwind_kph': 25.6,
#    'totalprecip_mm': 0.1,
#    'totalprecip_in': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 74.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'uv': 11.0},
#   'astro': {'sunrise': '06:29 AM',
#    'sunset': '08:14 PM',
#    'moonrise': '02:55 PM',
#    'moonset': '02:20 AM',
#    'moon_phase': 'Waxing Gibbous',
#    'moon_illumination': '69'},
#   'hour': [{'time_epoch': 1624075200,
#     'time': '2021-06-19 00:00',
#     'temp_c': 28.0,
#     'temp_f': 82.4,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 13.9,
#     'wind_kph': 22.3,
#     'wind_degree': 92,
#     'wind_dir': 'E',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 78,
#     'feelslike_c': 31.8,
#     'feelslike_f': 89.2,
#     'windchill_c': 28.0,
#     'windchill_f': 82.4,
#     'heatindex_c': 31.8,
#     'heatindex_f': 89.2,
#     'dewpoint_c': 23.5,
#     'dewpoint_f': 74.3,
#     'will_it_rain': 1,
#     'chance_of_rain': '75',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.6,
#     'gust_kph': 29.9,
#     'uv': 1.0},
#    {'time_epoch': 1624078800,
#     'time': '2021-06-19 01:00',
#     'temp_c': 27.9,
#     'temp_f': 82.2,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 15.0,
#     'wind_kph': 24.1,
#     'wind_degree': 103,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 77,
#     'feelslike_c': 31.7,
#     'feelslike_f': 89.1,
#     'windchill_c': 27.9,
#     'windchill_f': 82.2,
#     'heatindex_c': 31.7,
#     'heatindex_f': 89.1,
#     'dewpoint_c': 23.5,
#     'dewpoint_f': 74.3,
#     'will_it_rain': 1,
#     'chance_of_rain': '79',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 19.7,
#     'gust_kph': 31.7,
#     'uv': 1.0},
#    {'time_epoch': 1624082400,
#     'time': '2021-06-19 02:00',
#     'temp_c': 27.9,
#     'temp_f': 82.2,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 15.9,
#     'wind_kph': 25.6,
#     'wind_degree': 113,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 77,
#     'feelslike_c': 31.6,
#     'feelslike_f': 88.9,
#     'windchill_c': 27.9,
#     'windchill_f': 82.2,
#     'heatindex_c': 31.6,
#     'heatindex_f': 88.9,
#     'dewpoint_c': 23.4,
#     'dewpoint_f': 74.1,
#     'will_it_rain': 1,
#     'chance_of_rain': '82',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 21.0,
#     'gust_kph': 33.8,
#     'uv': 1.0},
#    {'time_epoch': 1624086000,
#     'time': '2021-06-19 03:00',
#     'temp_c': 27.9,
#     'temp_f': 82.2,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 15.7,
#     'wind_kph': 25.2,
#     'wind_degree': 119,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 78,
#     'cloud': 73,
#     'feelslike_c': 31.7,
#     'feelslike_f': 89.1,
#     'windchill_c': 27.9,
#     'windchill_f': 82.2,
#     'heatindex_c': 31.7,
#     'heatindex_f': 89.1,
#     'dewpoint_c': 23.6,
#     'dewpoint_f': 74.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '55',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 20.8,
#     'gust_kph': 33.5,
#     'uv': 1.0},
#    {'time_epoch': 1624089600,
#     'time': '2021-06-19 04:00',
#     'temp_c': 27.9,
#     'temp_f': 82.2,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 15.2,
#     'wind_kph': 24.5,
#     'wind_degree': 125,
#     'wind_dir': 'SE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 68,
#     'feelslike_c': 31.9,
#     'feelslike_f': 89.4,
#     'windchill_c': 27.9,
#     'windchill_f': 82.2,
#     'heatindex_c': 31.9,
#     'heatindex_f': 89.4,
#     'dewpoint_c': 23.8,
#     'dewpoint_f': 74.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '27',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 20.8,
#     'gust_kph': 33.5,
#     'uv': 1.0},
#    {'time_epoch': 1624093200,
#     'time': '2021-06-19 05:00',
#     'temp_c': 27.9,
#     'temp_f': 82.2,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 15.0,
#     'wind_kph': 24.1,
#     'wind_degree': 132,
#     'wind_dir': 'SE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 64,
#     'feelslike_c': 32.0,
#     'feelslike_f': 89.6,
#     'windchill_c': 27.9,
#     'windchill_f': 82.2,
#     'heatindex_c': 32.0,
#     'heatindex_f': 89.6,
#     'dewpoint_c': 24.0,
#     'dewpoint_f': 75.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 20.6,
#     'gust_kph': 33.1,
#     'uv': 1.0},
#    {'time_epoch': 1624096800,
#     'time': '2021-06-19 06:00',
#     'temp_c': 28.0,
#     'temp_f': 82.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 14.3,
#     'wind_kph': 23.0,
#     'wind_degree': 133,
#     'wind_dir': 'SE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 78,
#     'cloud': 58,
#     'feelslike_c': 32.0,
#     'feelslike_f': 89.6,
#     'windchill_c': 28.0,
#     'windchill_f': 82.4,
#     'heatindex_c': 32.0,
#     'heatindex_f': 89.6,
#     'dewpoint_c': 23.7,
#     'dewpoint_f': 74.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 19.5,
#     'gust_kph': 31.3,
#     'uv': 1.0},
#    {'time_epoch': 1624100400,
#     'time': '2021-06-19 07:00',
#     'temp_c': 28.2,
#     'temp_f': 82.8,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 13.6,
#     'wind_kph': 22.0,
#     'wind_degree': 135,
#     'wind_dir': 'SE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 51,
#     'feelslike_c': 32.0,
#     'feelslike_f': 89.6,
#     'windchill_c': 28.2,
#     'windchill_f': 82.8,
#     'heatindex_c': 32.0,
#     'heatindex_f': 89.6,
#     'dewpoint_c': 23.5,
#     'dewpoint_f': 74.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.3,
#     'gust_kph': 29.5,
#     'uv': 6.0},
#    {'time_epoch': 1624104000,
#     'time': '2021-06-19 08:00',
#     'temp_c': 28.3,
#     'temp_f': 82.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 13.0,
#     'wind_kph': 20.9,
#     'wind_degree': 136,
#     'wind_dir': 'SE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 74,
#     'cloud': 45,
#     'feelslike_c': 32.0,
#     'feelslike_f': 89.6,
#     'windchill_c': 28.3,
#     'windchill_f': 82.9,
#     'heatindex_c': 32.0,
#     'heatindex_f': 89.6,
#     'dewpoint_c': 23.2,
#     'dewpoint_f': 73.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.2,
#     'gust_kph': 27.7,
#     'uv': 7.0},
#    {'time_epoch': 1624107600,
#     'time': '2021-06-19 09:00',
#     'temp_c': 28.5,
#     'temp_f': 83.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 13.0,
#     'wind_kph': 20.9,
#     'wind_degree': 137,
#     'wind_dir': 'SE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 72,
#     'cloud': 36,
#     'feelslike_c': 32.1,
#     'feelslike_f': 89.8,
#     'windchill_c': 28.5,
#     'windchill_f': 83.3,
#     'heatindex_c': 32.1,
#     'heatindex_f': 89.8,
#     'dewpoint_c': 23.0,
#     'dewpoint_f': 73.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.6,
#     'gust_kph': 26.6,
#     'uv': 7.0},
#    {'time_epoch': 1624111200,
#     'time': '2021-06-19 10:00',
#     'temp_c': 28.7,
#     'temp_f': 83.7,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 12.8,
#     'wind_kph': 20.5,
#     'wind_degree': 138,
#     'wind_dir': 'SE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 70,
#     'cloud': 26,
#     'feelslike_c': 32.2,
#     'feelslike_f': 90.0,
#     'windchill_c': 28.7,
#     'windchill_f': 83.7,
#     'heatindex_c': 32.2,
#     'heatindex_f': 90.0,
#     'dewpoint_c': 22.7,
#     'dewpoint_f': 72.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.1,
#     'gust_kph': 25.9,
#     'uv': 7.0},
#    {'time_epoch': 1624114800,
#     'time': '2021-06-19 11:00',
#     'temp_c': 28.9,
#     'temp_f': 84.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 12.8,
#     'wind_kph': 20.5,
#     'wind_degree': 139,
#     'wind_dir': 'SE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 17,
#     'feelslike_c': 32.3,
#     'feelslike_f': 90.1,
#     'windchill_c': 28.9,
#     'windchill_f': 84.0,
#     'heatindex_c': 32.3,
#     'heatindex_f': 90.1,
#     'dewpoint_c': 22.5,
#     'dewpoint_f': 72.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.4,
#     'gust_kph': 24.8,
#     'uv': 7.0},
#    {'time_epoch': 1624118400,
#     'time': '2021-06-19 12:00',
#     'temp_c': 29.0,
#     'temp_f': 84.2,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 12.5,
#     'wind_kph': 20.2,
#     'wind_degree': 135,
#     'wind_dir': 'SE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 14,
#     'feelslike_c': 32.4,
#     'feelslike_f': 90.3,
#     'windchill_c': 29.0,
#     'windchill_f': 84.2,
#     'heatindex_c': 32.4,
#     'heatindex_f': 90.3,
#     'dewpoint_c': 22.5,
#     'dewpoint_f': 72.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.0,
#     'gust_kph': 24.1,
#     'uv': 7.0},
#    {'time_epoch': 1624122000,
#     'time': '2021-06-19 13:00',
#     'temp_c': 29.1,
#     'temp_f': 84.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 12.3,
#     'wind_kph': 19.8,
#     'wind_degree': 132,
#     'wind_dir': 'SE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 67,
#     'cloud': 12,
#     'feelslike_c': 32.6,
#     'feelslike_f': 90.7,
#     'windchill_c': 29.1,
#     'windchill_f': 84.4,
#     'heatindex_c': 32.6,
#     'heatindex_f': 90.7,
#     'dewpoint_c': 22.4,
#     'dewpoint_f': 72.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.5,
#     'gust_kph': 23.4,
#     'uv': 7.0},
#    {'time_epoch': 1624125600,
#     'time': '2021-06-19 14:00',
#     'temp_c': 29.2,
#     'temp_f': 84.6,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 12.1,
#     'wind_kph': 19.4,
#     'wind_degree': 128,
#     'wind_dir': 'SE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 67,
#     'cloud': 10,
#     'feelslike_c': 32.7,
#     'feelslike_f': 90.9,
#     'windchill_c': 29.2,
#     'windchill_f': 84.6,
#     'heatindex_c': 32.7,
#     'heatindex_f': 90.9,
#     'dewpoint_c': 22.4,
#     'dewpoint_f': 72.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.1,
#     'gust_kph': 22.7,
#     'uv': 7.0},
#    {'time_epoch': 1624129200,
#     'time': '2021-06-19 15:00',
#     'temp_c': 29.2,
#     'temp_f': 84.6,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 11.9,
#     'wind_kph': 19.1,
#     'wind_degree': 125,
#     'wind_dir': 'SE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 12,
#     'feelslike_c': 32.8,
#     'feelslike_f': 91.0,
#     'windchill_c': 29.2,
#     'windchill_f': 84.6,
#     'heatindex_c': 32.8,
#     'heatindex_f': 91.0,
#     'dewpoint_c': 22.6,
#     'dewpoint_f': 72.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.9,
#     'gust_kph': 22.3,
#     'uv': 7.0},
#    {'time_epoch': 1624132800,
#     'time': '2021-06-19 16:00',
#     'temp_c': 29.1,
#     'temp_f': 84.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 11.4,
#     'wind_kph': 18.4,
#     'wind_degree': 123,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 15,
#     'feelslike_c': 32.8,
#     'feelslike_f': 91.0,
#     'windchill_c': 29.1,
#     'windchill_f': 84.4,
#     'heatindex_c': 32.8,
#     'heatindex_f': 91.0,
#     'dewpoint_c': 22.7,
#     'dewpoint_f': 72.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.6,
#     'gust_kph': 22.0,
#     'uv': 7.0},
#    {'time_epoch': 1624136400,
#     'time': '2021-06-19 17:00',
#     'temp_c': 29.1,
#     'temp_f': 84.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 11.2,
#     'wind_kph': 18.0,
#     'wind_degree': 121,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 69,
#     'cloud': 17,
#     'feelslike_c': 32.9,
#     'feelslike_f': 91.2,
#     'windchill_c': 29.1,
#     'windchill_f': 84.4,
#     'heatindex_c': 32.9,
#     'heatindex_f': 91.2,
#     'dewpoint_c': 22.9,
#     'dewpoint_f': 73.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.4,
#     'gust_kph': 21.6,
#     'uv': 7.0},
#    {'time_epoch': 1624140000,
#     'time': '2021-06-19 18:00',
#     'temp_c': 28.9,
#     'temp_f': 84.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 11.0,
#     'wind_kph': 17.6,
#     'wind_degree': 117,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 71,
#     'cloud': 28,
#     'feelslike_c': 32.8,
#     'feelslike_f': 91.0,
#     'windchill_c': 28.9,
#     'windchill_f': 84.0,
#     'heatindex_c': 32.8,
#     'heatindex_f': 91.0,
#     'dewpoint_c': 23.1,
#     'dewpoint_f': 73.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.4,
#     'gust_kph': 21.6,
#     'uv': 7.0},
#    {'time_epoch': 1624143600,
#     'time': '2021-06-19 19:00',
#     'temp_c': 28.7,
#     'temp_f': 83.7,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 10.7,
#     'wind_kph': 17.3,
#     'wind_degree': 113,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 40,
#     'feelslike_c': 32.7,
#     'feelslike_f': 90.9,
#     'windchill_c': 28.7,
#     'windchill_f': 83.7,
#     'heatindex_c': 32.7,
#     'heatindex_f': 90.9,
#     'dewpoint_c': 23.4,
#     'dewpoint_f': 74.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.4,
#     'gust_kph': 21.6,
#     'uv': 7.0},
#    {'time_epoch': 1624147200,
#     'time': '2021-06-19 20:00',
#     'temp_c': 28.5,
#     'temp_f': 83.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 10.5,
#     'wind_kph': 16.9,
#     'wind_degree': 109,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 51,
#     'feelslike_c': 32.6,
#     'feelslike_f': 90.7,
#     'windchill_c': 28.5,
#     'windchill_f': 83.3,
#     'heatindex_c': 32.6,
#     'heatindex_f': 90.7,
#     'dewpoint_c': 23.6,
#     'dewpoint_f': 74.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.4,
#     'gust_kph': 21.6,
#     'uv': 7.0},
#    {'time_epoch': 1624150800,
#     'time': '2021-06-19 21:00',
#     'temp_c': 28.4,
#     'temp_f': 83.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 11.4,
#     'wind_kph': 18.4,
#     'wind_degree': 108,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 52,
#     'feelslike_c': 32.7,
#     'feelslike_f': 90.9,
#     'windchill_c': 28.4,
#     'windchill_f': 83.1,
#     'heatindex_c': 32.7,
#     'heatindex_f': 90.9,
#     'dewpoint_c': 23.9,
#     'dewpoint_f': 75.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.8,
#     'gust_kph': 23.8,
#     'uv': 1.0},
#    {'time_epoch': 1624154400,
#     'time': '2021-06-19 22:00',
#     'temp_c': 28.4,
#     'temp_f': 83.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 12.3,
#     'wind_kph': 19.8,
#     'wind_degree': 106,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 78,
#     'cloud': 52,
#     'feelslike_c': 32.8,
#     'feelslike_f': 91.0,
#     'windchill_c': 28.4,
#     'windchill_f': 83.1,
#     'heatindex_c': 32.8,
#     'heatindex_f': 91.0,
#     'dewpoint_c': 24.1,
#     'dewpoint_f': 75.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.3,
#     'gust_kph': 26.3,
#     'uv': 1.0},
#    {'time_epoch': 1624158000,
#     'time': '2021-06-19 23:00',
#     'temp_c': 28.3,
#     'temp_f': 82.9,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 13.2,
#     'wind_kph': 21.2,
#     'wind_degree': 105,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 53,
#     'feelslike_c': 32.9,
#     'feelslike_f': 91.2,
#     'windchill_c': 28.3,
#     'windchill_f': 82.9,
#     'heatindex_c': 32.9,
#     'heatindex_f': 91.2,
#     'dewpoint_c': 24.4,
#     'dewpoint_f': 75.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.7,
#     'gust_kph': 28.4,
#     'uv': 1.0}]}]

# %%
for hourly_forecast in data['forecast']['forecastday']:
    for time in hourly_forecast['hour']:
        if time['cloud'] > 50:
            print(f"For {time['time']}, it is {time['temp_f']} degrees Fahrenheit and cloudy")
        else:
            print(f"For {time['time']}, it is {time['temp_f']} degrees Fahrenheit")
# Out:
# For 2021-06-20 00:00, it is 82.9 degrees Fahrenheit and cloudy
# For 2021-06-20 01:00, it is 82.9 degrees Fahrenheit and cloudy
# For 2021-06-20 02:00, it is 82.9 degrees Fahrenheit and cloudy
# For 2021-06-20 03:00, it is 82.8 degrees Fahrenheit and cloudy
# For 2021-06-20 04:00, it is 82.4 degrees Fahrenheit and cloudy
# For 2021-06-20 05:00, it is 82.2 degrees Fahrenheit and cloudy
# For 2021-06-20 06:00, it is 82.4 degrees Fahrenheit and cloudy
# For 2021-06-20 07:00, it is 82.8 degrees Fahrenheit and cloudy
# For 2021-06-20 08:00, it is 82.9 degrees Fahrenheit and cloudy
# For 2021-06-20 09:00, it is 83.7 degrees Fahrenheit and cloudy
# For 2021-06-20 10:00, it is 84.2 degrees Fahrenheit and cloudy
# For 2021-06-20 11:00, it is 84.9 degrees Fahrenheit and cloudy
# For 2021-06-20 12:00, it is 85.1 degrees Fahrenheit and cloudy
# For 2021-06-20 13:00, it is 85.1 degrees Fahrenheit and cloudy
# For 2021-06-20 14:00, it is 85.3 degrees Fahrenheit and cloudy
# For 2021-06-20 15:00, it is 85.1 degrees Fahrenheit and cloudy
# For 2021-06-20 16:00, it is 85.1 degrees Fahrenheit and cloudy
# For 2021-06-20 17:00, it is 84.9 degrees Fahrenheit and cloudy
# For 2021-06-20 18:00, it is 84.7 degrees Fahrenheit and cloudy
# For 2021-06-20 19:00, it is 84.4 degrees Fahrenheit
# For 2021-06-20 20:00, it is 84.2 degrees Fahrenheit
# For 2021-06-20 21:00, it is 84.0 degrees Fahrenheit
# For 2021-06-20 22:00, it is 83.7 degrees Fahrenheit and cloudy
# For 2021-06-20 23:00, it is 83.5 degrees Fahrenheit and cloudy

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
count = 0

for hourly_forecast in data['forecast']['forecastday']:
    for time in hourly_forecast['hour']:
        if time['temp_f'] > 85:
           count = count + 1

print(count)
# Out:
# 0

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2020? How about 2012? 2007? How far back does the API allow you to go?
#
# - *Tip: You'll need to use latitude/longitude. You can ask Google where Central Park is, it knows*
# - *Tip: Remember when latitude/longitude might use negative numbers*

# %%
for hourly_forecast in data['forecast']['forecastday']:
    for time in hourly_forecast['hour']:
        if time['temp_f'] > 85:
           count = count + 1

# %%
count
# Out:
# 0
